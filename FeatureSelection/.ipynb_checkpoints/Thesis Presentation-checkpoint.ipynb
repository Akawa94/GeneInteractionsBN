# %%
import seaborn as sns
import pandas as pd
import numpy as np
import pickle
import os
import matplotlib.pyplot as plt
import bz2 # for pickling and unplicking large files

# %%
main_directory = '/home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/'
with open(main_directory+'total_unified_results_v2.pickle', 'rb') as f:
    total_results = pickle.load(f)

# %%
total_results={}

# %%
for directory in os.listdir(main_directory):
    if '.pickle' in directory or '.csv' in directory or 'censored' not in directory:
        continue
    print(directory)
    with open(main_directory+directory+'_unified_results.pickle','rb') as f:
        total_results[directory] = pickle.load(f)
# Out:
# censored_Jnk
# censored_Ikk2
# censored_LEF1
# censored_IRF4
# censored_MYC
# censored_Erk
# censored_CTNNB1

# %%
df = pd.DataFrame(columns=["Número de nodos", "Media Geométrica", "Método de Selección de Atributos","Clasificador", "Origen"])
for key in total_results:
    for f_key in total_results[key]:
        if 'AGA' not in f_key:
            for c_key in total_results[key][f_key]:
                for t_key in total_results[key][f_key][c_key]:
                    df = df.append({
                        "Número de nodos":int(t_key.split('top')[1]), 
                        "Media Geométrica":total_results[key][f_key][c_key][t_key],
                        "Método de Selección de Atributos":f_key,
                        "Clasificador":c_key,
                        "Origen":key
                    }, ignore_index=True)

# %%
classificator_list = list(set(df["Clasificador"]))
origin_list = list(set(df["Origen"]))

#f, axes = plt.subplots(len(classificator_list), len(origin_list))
f, axes = plt.subplots(len(origin_list),len(classificator_list), figsize=(30,35))
for i in range(0,len(classificator_list)):
    for j in range(0,len(origin_list)):        
        # Draw a pointplot to show pulse as a function of three categorical factors
        sns.set_color_codes("pastel")
        #g = sns.barplot(x='Node name',y='Distance',hue='Feature Selection Method', data=b_plot_df)
        g = sns.factorplot(x="Número de nodos",y="Media Geométrica",hue='Método de Selección de Atributos', 
                           data=df.query('Clasificador == "'+classificator_list[i]+'" and Origen=="'+origin_list[j]+'"'), palette="husl", 
                            alpha=0.5, ax=axes[j,i])
        # g = sns.FacetGrid(b_plot_df,hue="Feature Selection Method", size=15, aspect=2)
        # g.map(plt.scatter, "Node name", "Distance", alpha=.5)
        #g.set_yticklabels(np.arange(0,2,0.15))
        #g.set_xticklabels(rotation=90)
        #g.add_legend()
        axes[j,i].title.set_text(classificator_list[i]+" - "+origin_list[j])
# Out:
# /home/a20114261/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
aga_df = pd.DataFrame(columns=["Fracción Mínima de Aparación", "GMedia", "Clasificador", "Método de Selección de Atributos","Origen"])
for key in total_results:
    for f_key in total_results[key]:
        if 'AGA' in f_key:
            #print(total_results[key][f_key])
            for fr_key in total_results[key][f_key]:
                for c_key in total_results[key][f_key][fr_key]:
                    m_key = 'MMPCOPT'
                    if 'OPT' not in f_key:
                        m_key = 'MMRWPC'
                    aga_df = aga_df.append({
                        "Fracción Mínima de Aparación":float(fr_key), 
                        "GMedia":total_results[key][f_key][fr_key][c_key]['unique'],                        
                        "Clasificador":c_key,
                        "Método de Selección de Atributos": m_key,
                        "Origen":key
                    }, ignore_index=True)

# %%
classificator_list = list(set(df["Clasificador"]))
origin_list = list(set(df["Origen"]))

#f, axes = plt.subplots(len(classificator_list), len(origin_list))
f, axes = plt.subplots(len(origin_list),len(classificator_list),figsize=(30,35))
for i in range(0,len(classificator_list)):
    for j in range(0,len(origin_list)):        
        # Draw a pointplot to show pulse as a function of three categorical factors
        sns.set_color_codes("pastel")
        #g = sns.barplot(x='Node name',y='Distance',hue='Feature Selection Method', data=b_plot_df)
        g = sns.factorplot(x="Fracción Mínima de Aparación",y="GMedia", hue="Método de Selección de Atributos",
                           data=aga_df.query('Clasificador == "'+classificator_list[i]+'" and Origen=="'+origin_list[j]+'"'), palette="husl", 
                            alpha=0.5, ax=axes[j,i])
        # g = sns.FacetGrid(b_plot_df,hue="Feature Selection Method", size=15, aspect=2)
        # g.map(plt.scatter, "Node name", "Distance", alpha=.5)
        #g.set_yticklabels(np.arange(0,2,0.15))
        #g.set_xticklabels(rotation=90)
        #g.add_legend()
        axes[j,i].title.set_text(classificator_list[i]+" - "+origin_list[j])
# Out:
# /home/a20114261/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
results_save_folder = 'expanded_results/'
fourth_results_df = pd.DataFrame(columns=["SelectorAtributos","Clasificador","Top","GMedia","Origen"])
for directory in os.listdir(main_directory):
    if '.pickle' in directory or 'censored' not in directory or '.csv' in directory:
        continue
    print(directory)
    file_pre = main_directory+results_save_folder+directory
    for i in range(0,100):
        print(file_pre+'_sr_p'+str(i)+'.bz2')
        with bz2.open(file_pre+'_sr_p'+str(i)+'.bz2','rb',9) as f:
            s_data = pickle.load(f)
        print(i)
        for key in (list(s_data.keys())):
            print(key)
            for s_key in list(s_data[key].keys()):
                for t_key in list(s_data[key][s_key].keys()):
                    fourth_results_df = fourth_results_df.append({
                        "SelectorAtributos":key,
                        "Clasificador":s_key,
                        "Top":t_key,
                        "GMedia":s_data[key][s_key][t_key]['g-mean'],
                        "Origen":directory,
                    }, ignore_index=True)
# Out:
# censored_Jnk
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p0.bz2
# 0
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p1.bz2
# 1
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p2.bz2
# 2
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p3.bz2
# 3
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p4.bz2
# 4
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p5.bz2
# 5
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p6.bz2
# 6
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p7.bz2
# 7
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p8.bz2
# 8
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p9.bz2
# 9
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p10.bz2
# 10
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p11.bz2
# 11
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p12.bz2
# 12
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p13.bz2
# 13
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p14.bz2
# 14
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p15.bz2
# 15
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p16.bz2
# 16
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p17.bz2
# 17
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p18.bz2
# 18
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p19.bz2
# 19
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p20.bz2
# 20
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p21.bz2
# 21
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p22.bz2
# 22
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p23.bz2
# 23
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p24.bz2
# 24
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p25.bz2
# 25
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p26.bz2
# 26
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p27.bz2
# 27
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p28.bz2
# 28
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p29.bz2
# 29
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p30.bz2
# 30
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p31.bz2
# 31
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p32.bz2
# 32
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p33.bz2
# 33
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p34.bz2
# 34
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p35.bz2
# 35
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p36.bz2
# 36
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p37.bz2
# 37
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p38.bz2
# 38
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p39.bz2
# 39
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p40.bz2
# 40
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p41.bz2
# 41
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p42.bz2
# 42
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p43.bz2
# 43
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p44.bz2
# 44
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p45.bz2
# 45
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p46.bz2
# 46
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p47.bz2
# 47
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p48.bz2
# 48
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p49.bz2
# 49
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p50.bz2
# 50
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p51.bz2
# 51
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p52.bz2
# 52
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p53.bz2
# 53
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p54.bz2
# 54
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p55.bz2
# 55
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p56.bz2
# 56
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p57.bz2
# 57
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p58.bz2
# 58
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p59.bz2
# 59
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p60.bz2
# 60
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p61.bz2
# 61
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p62.bz2
# 62
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p63.bz2
# 63
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p64.bz2
# 64
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p65.bz2
# 65
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p66.bz2
# 66
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p67.bz2
# 67
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p68.bz2
# 68
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_p69.bz2
# 69
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_Jnk_sr_
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p47.bz2
# 47
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p48.bz2
# 48
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p49.bz2
# 49
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p50.bz2
# 50
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p51.bz2
# 51
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p52.bz2
# 52
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p53.bz2
# 53
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p54.bz2
# 54
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p55.bz2
# 55
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p56.bz2
# 56
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p57.bz2
# 57
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p58.bz2
# 58
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p59.bz2
# 59
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p60.bz2
# 60
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p61.bz2
# 61
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p62.bz2
# 62
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p63.bz2
# 63
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p64.bz2
# 64
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p65.bz2
# 65
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p66.bz2
# 66
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p67.bz2
# 67
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p68.bz2
# 68
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p69.bz2
# 69
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p70.bz2
# 70
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p71.bz2
# 71
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p72.bz2
# 72
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p73.bz2
# 73
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p74.bz2
# 74
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p75.bz2
# 75
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p76.bz2
# 76
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p77.bz2
# 77
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p78.bz2
# 78
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p79.bz2
# 79
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p80.bz2
# 80
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p81.bz2
# 81
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p82.bz2
# 82
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p83.bz2
# 83
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p84.bz2
# 84
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p85.bz2
# 85
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p86.bz2
# 86
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p87.bz2
# 87
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p88.bz2
# 88
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p89.bz2
# 89
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p90.bz2
# 90
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p91.bz2
# 91
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p92.bz2
# 92
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p93.bz2
# 93
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p94.bz2
# 94
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p95.bz2
# 95
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p96.bz2
# 96
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p97.bz2
# 97
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p98.bz2
# 98
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt
# /home/a20114261/sdelrio/GeneInteractions/GeneInteractionsBN_Datasets/Balanced_Batches/expanded_results/censored_CTNNB1_sr_p99.bz2
# 99
# MI
# TTEST_ind
# TTEST_rel
# MMRWPC
# MMPC_opt

# %%
classificator_list = list(set(fourth_results_df["Clasificador"]))
origin_list = list(set(fourth_results_df["Origen"]))
f, axes = plt.subplots(len(origin_list),len(classificator_list), figsize=(30,35))
for i in range(0,len(classificator_list)):
    for j in range(0,len(origin_list)):        
        # Draw a pointplot to show pulse as a function of three categorical factors
        sns.set_color_codes("pastel")
        #g = sns.barplot(x='Node name',y='Distance',hue='Feature Selection Method', data=b_plot_df)
        g = sns.factorplot(x="Top",y="GMedia",hue='SelectorAtributos', 
                           data=fourth_results_df.query('Clasificador == "'+classificator_list[i]+'" and Origen=="'+origin_list[j]+'"'), palette="husl", 
                            alpha=0.5, ax=axes[j,i])
        # g = sns.FacetGrid(b_plot_df,hue="Feature Selection Method", size=15, aspect=2)
        # g.map(plt.scatter, "Node name", "Distance", alpha=.5)
        #g.set_yticklabels(np.arange(0,2,0.15))
        #g.set_xticklabels(rotation=90)
        #g.add_legend()
        axes[j,i].title.set_text(classificator_list[i]+" - "+origin_list[j])
# Out:
# /home/a20114261/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
fourth_results_df.query('GMedia>0.60 and SelectorAtributos == "TTEST_rel"')
# Out:
#       SelectorAtributos Clasificador    Top    GMedia           Origen
# 10230         TTEST_rel           NB   top2  0.638041    censored_LEF1
# 10233         TTEST_rel           NB  top10  0.645826    censored_LEF1
# 10234         TTEST_rel           NB  top15  0.633039    censored_LEF1
# 10240         TTEST_rel           LR   top2  0.638041    censored_LEF1
# 10241         TTEST_rel           LR   top3  0.621269    censored_LEF1
# 10242         TTEST_rel           LR   top5  0.652427    censored_LEF1
# 10243         TTEST_rel           LR  top10  0.625604    censored_LEF1
# 10244         TTEST_rel           LR  top15  0.610330    censored_LEF1
# 10282         TTEST_rel           NB   top3  0.617466    censored_LEF1
# 10283         TTEST_rel           NB   top5  0.605081    censored_LEF1
# 10284         TTEST_rel           NB  top10  0.607888    censored_LEF1
# 10285         TTEST_rel           NB  top15  0.623012    censored_LEF1
# 10287         TTEST_rel          DTC   top3  0.602740    censored_LEF1
# 10291         TTEST_rel           LR   top2  0.638041    censored_LEF1
# 10292         TTEST_rel           LR   top3  0.633095    censored_LEF1
# 10293         TTEST_rel           LR   top5  0.628359    censored_LEF1
# 10294         TTEST_rel           LR  top10  0.648588    censored_LEF1
# 10295         TTEST_rel           LR  top15  0.641968    censored_LEF1
# 10336         TTEST_rel           NB  top15  0.614198    censored_LEF1
# 10342         TTEST_rel           LR   top2  0.638041    censored_LEF1
# 10343         TTEST_rel           LR   top3  0.609279    censored_LEF1
# 10344         TTEST_rel           LR   top5  0.628504    censored_LEF1
# 10345         TTEST_rel           LR  top10  0.642897    censored_LEF1
# 10346         TTEST_rel           LR  top15  0.638324    censored_LEF1
# 10383         TTEST_rel           NB   top2  0.638041    censored_LEF1
# 10385         TTEST_rel           NB   top5  0.639274    censored_LEF1
# 10386         TTEST_rel           NB  top10  0.625989    censored_LEF1
# 10387         TTEST_rel           NB  top15  0.624943    censored_LEF1
# 10388         TTEST_rel          DTC   top2  0.638041    censored_LEF1
# 10393         TTEST_rel           LR   top2  0.638041    censored_LEF1
# ...                 ...          ...    ...       ...              ...
# 15179         TTEST_rel           NB   top5  0.652852    censored_LEF1
# 15180         TTEST_rel           NB  top10  0.632600    censored_LEF1
# 15181         TTEST_rel           NB  top15  0.616476    censored_LEF1
# 15187         TTEST_rel           LR   top2  0.638041    censored_LEF1
# 15188         TTEST_rel           LR   top3  0.628913    censored_LEF1
# 15189         TTEST_rel           LR   top5  0.648196    censored_LEF1
# 15190         TTEST_rel           LR  top10  0.649416    censored_LEF1
# 15191         TTEST_rel           LR  top15  0.636435    censored_LEF1
# 15228         TTEST_rel           NB   top2  0.638041    censored_LEF1
# 15229         TTEST_rel           NB   top3  0.609430    censored_LEF1
# 15230         TTEST_rel           NB   top5  0.604490    censored_LEF1
# 15231         TTEST_rel           NB  top10  0.616485    censored_LEF1
# 15232         TTEST_rel           NB  top15  0.623604    censored_LEF1
# 15234         TTEST_rel          DTC   top3  0.621984    censored_LEF1
# 15235         TTEST_rel          DTC   top5  0.627529    censored_LEF1
# 15238         TTEST_rel           LR   top2  0.638041    censored_LEF1
# 15239         TTEST_rel           LR   top3  0.647123    censored_LEF1
# 15240         TTEST_rel           LR   top5  0.642077    censored_LEF1
# 15241         TTEST_rel           LR  top10  0.620709    censored_LEF1
# 15242         TTEST_rel           LR  top15  0.612675    censored_LEF1
# 15279         TTEST_rel           NB   top2  0.638041    censored_LEF1
# 15282         TTEST_rel           NB  top10  0.619036    censored_LEF1
# 15286         TTEST_rel          DTC   top5  0.609059    censored_LEF1
# 15289         TTEST_rel           LR   top2  0.638041    censored_LEF1
# 15290         TTEST_rel           LR   top3  0.639031    censored_LEF1
# 15291         TTEST_rel           LR   top5  0.635811    censored_LEF1
# 15292         TTEST_rel           LR  top10  0.610222    censored_LEF1
# 15293         TTEST_rel           LR  top15  0.616866    censored_LEF1
# 33900         TTEST_rel          DTC   top3  0.601616  censored_CTNNB1
# 35127         TTEST_rel          DTC  top15  0.615638  censored_CTNNB1
#
# [779 rows x 5 columns]

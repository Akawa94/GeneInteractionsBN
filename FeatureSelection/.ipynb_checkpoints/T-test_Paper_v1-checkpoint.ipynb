# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind
from scipy.stats import ttest_rel
from operator import itemgetter
import os
import gc
from sklearn.svm import LinearSVC
from joblib import Parallel, delayed
from sklearn.naive_bayes import GaussianNB

# %%
main_directory= '/home/sdelrio/alarm_datasets/Alarm10/'
save_folder='/home/sdelrio/alarm_datasets/log_results/'

if not os.path.exists(main_directory):
    print("Bad routing.")
preselected_nodes=[] # will have [node_str,balance_ranking]
# so far, we need Node, size of estimated pc set per filename, balance ranking
ff = open(save_folder+'mmpc_partitioned/alarm10_binary_nodes_selected.txt','r')
for e in ff.read().split('\n'):
    spl_line = e.split(';')
    if (len(spl_line[0])==0):
        continue
    preselected_nodes.append([spl_line[0].split('@')[0],float(spl_line[1])])
ff.close()

# %%
#info recovery
len_recovery_proof=[]
ff = open(save_folder+'mmpc_partitioned/supercpc_log.txt','r')
recovery_read = ff.read().split('\n')
for line in recovery_read:
    sub_line=line.split(';')
    if (len(sub_line)<3):
        continue
    p_dict={}
    p_dict['dataset']=sub_line[0]
    p_dict['TargetNode']=sub_line[1].split('@')[0]
    p_dict['supercpc_len']=len(sub_line[2].split('_'))
    len_recovery_proof.append(p_dict)
ff.close()

# %%
graph_heads = []
for i in range(1,371):
    graph_heads.append('Node'+str(i))

# %%
# %%time
files_dict = {}
for filename in os.listdir(main_directory):
    temp_df = pd.read_csv(main_directory+filename,delimiter='  ',header=None, engine='python')
    temp_df.columns = graph_heads
    files_dict[filename] = temp_df
    print(filename)

# %%
# %%time
print("======================================================================================")
print("T-test Algorithm")
print("======================================================================================")
PCs = Parallel(n_jobs=10)(map(delayed(Ttest_scoring),len_recovery_proof))

# %%
def Ttest_scoring(PobDict):
    X = files_dict[PobDict['dataset']]
    #print("======================================================================================")
    # selection of target
    evaluated_nodes=[]
    for node in X.columns:
        if (node != PobDict['TargetNode']):            
            evaluated_nodes.append([node,ttest_ind(X[PobDict['TargetNode']],X[node])])
    PobDict['evaluated_nodes']= evaluated_nodes
    pc_length = PobDict['supercpc_len']
    PobDict['PC'] = [x[0] for x in sorted(PobDict['evaluated_nodes'],key=lambda x: x[1][1],reverse=True)[:pc_length]]
    print('Finished analysing '+PobDict['TargetNode'])
    return PobDict

# %%
CandidateNBScore_Parallel(PCs[0])
# Out:
# Exiting Candidate NB Scoring function
# {'PC': ['Node49',
#   'Node69',
#   'Node242',
#   'Node211',
#   'Node258',
#   'Node349',
#   'Node178',
#   'Node160',
#   'Node275',
#   'Node233',
#   'Node17',
#   'Node43',
#   'Node57',
#   'Node67',
#   'Node90',
#   'Node123',
#   'Node312',
#   'Node131',
#   'Node86',
#   'Node164',
#   'Node16'],
#  'TargetNode': 'Node101',
#  'class_precisions': [[[[0, 24, 0.9166666666666666],
#     [1, 476, 0.13865546218487396]],
#    'Alarm10_s500_v7.txt'],
#   [[[0, 6, 0.8333333333333334], [1, 494, 0.14979757085020243]],
#    'Alarm10_s500_v6.txt'],
#   [[[0, 7, 1.0], [1, 493, 0.15618661257606492]], 'Alarm10_s500_v2.txt'],
#   [[[0, 9, 1.0], [1, 491, 0.1384928716904277]], 'Alarm10_s500_v1.txt'],
#   [[[0, 8, 1.0], [1, 492, 0.1524390243902439]], 'Alarm10_s500_v4.txt'],
#   [[[0, 10, 1.0], [1, 490, 0.12653061224489795]], 'Alarm10_s500_v3.txt'],
#   [[[0, 14, 0.7857142857142857], [1, 486, 0.14609053497942387]],
#    'Alarm10_s500_v5.txt'],
#   [[[0, 8, 0.875], [1, 492, 0.1565040650406504]], 'Alarm10_s500_v10.txt'],
#   [[[0, 15, 0.9333333333333333], [1, 485, 0.15463917525773196]],
#    'Alarm10_s500_v8.txt']],
#  'dataset': 'Alarm10_s500_v9.txt',
#  'evaluated_nodes': [['Node1',
#    Ttest_indResult(statistic=17.496260536185872, pvalue=5.475187226918702e-60)],
#   ['Node2',
#    Ttest_indResult(statistic=-14.53932410477363, pvalue=1.3936374715494905e-43)],
#   ['Node3',
#    Ttest_indResult(statistic=-1.9240963078904845, pvalue=0.05462662838791718)],
#   ['Node4',
#    Ttest_indResult(statistic=-7.020990271209761, pvalue=4.067734489212553e-12)],
#   ['Node5',
#    Ttest_indResult(statistic=11.746635907607946, pvalue=6.200991017790613e-30)],
#   ['Node6',
#    Ttest_indResult(statistic=1.2388730170581264, pvalue=0.21568381765871436)],
#   ['Node7',
#    Ttest_indResult(statistic=-4.304680018456917, pvalue=1.8370723694116205e-05)],
#   ['Node8',
#    Ttest_indResult(statistic=-2.713067117530169, pvalue=0.006781115258069462)],
#   ['Node9',
#    Ttest_indResult(statistic=6.330635092303813, pvalue=3.6839842145408775e-10)],
#   ['Node10',
#    Ttest_indResult(statistic=3.5886952393264018, pvalue=0.0003484879349072716)],
#   ['Node11',
#    Ttest_indResult(statistic=3.1501972880720888, pvalue=0.0016801498995579367)],
#   ['Node12',
#    Ttest_indResult(statistic=1.6204283213628603, pvalue=0.10545619943142864)],
#   ['Node13',
#    Ttest_indResult(statistic=-7.038251123187518, pvalue=3.6154789338522777e-12)],
#   ['Node14',
#    Ttest_indResult(statistic=36.547960169002025, pvalue=2.6904218695255094e-186)],
#   ['Node15', Ttest_indResult(statistic=-60.6013857522435, pvalue=0.0)],
#   ['Node16',
#    Ttest_indResult(statistic=-0.8342342247300433, pvalue=0.4043486415292804)],
#   ['Node17',
#    Ttest_indResult(statistic=-0.632356975945674, pvalue=0.527298482243375)],
#   ['Node18',
#    Ttest_indResult(statistic=8.699567312162358, pvalue=1.354381468143819e-17)],
#   ['Node19',
#    Ttest_indResult(statistic=39.370284885493504, pvalue=2.4038263864780345e-205)],
#   ['Node20',
#    Ttest_indResult(statistic=-2.204761697579777, pvalue=0.027698331980062472)],
#   ['Node21',
#    Ttest_indResult(statistic=34.213013568293285, pvalue=2.2664513417944565e-170)],
#   ['Node22',
#    Ttest_indResult(statistic=42.068397343225634, pvalue=2.779469005517831e-223)],
#   ['Node23',
#    Ttest_indResult(statistic=31.82736268452884, pvalue=5.2036159622269544e-154)],
#   ['Node24',
#    Ttest_indResult(statistic=1.9866632113040346, pvalue=0.04723284883696781)],
#   ['Node25', Ttest_indResult(statistic=-69.5198369716348, pvalue=0.0)],
#   ['Node26',
#    Ttest_indResult(statistic=-3.006280711550979, pvalue=0.0027108335066842043)],
#   ['Node27',
#    Ttest_indResult(statistic=1.844092152240028, pvalue=0.06546597200902775)],
#   ['Node28',
#    Ttest_indResult(statistic=5.981474171693862, pvalue=3.0776583707554416e-09)],
#   ['Node29',
#    Ttest_indResult(statistic=33.73628671993066, pvalue=4.166937800182726e-167)],
#   ['Node30',
#    Ttest_indResult(statistic=-2.204761697579777, pvalue=0.027698331980062472)],
#   ['Node31',
#    Ttest_indResult(statistic=9.983806952382167, pvalue=1.942732178920386e-22)],
#   ['Node32',
#    Ttest_indResult(statistic=-5.0161673861224925, pvalue=6.237053608088419e-07)],
#   ['Node33',
#    Ttest_indResult(statistic=-3.943685824553039, pvalue=8.584517445981782e-05)],
#   ['Node34',
#    Ttest_indResult(statistic=5.940720311361878, pvalue=3.915787953874238e-09)],
#   ['Node35',
#    Ttest_indResult(statistic=-6.295257258285287, pvalue=4.59006853605789e-10)],
#   ['Node36',
#    Ttest_indResult(statistic=2.2627620592870605, pvalue=0.023864598268239133)],
#   ['Node37',
#    Ttest_indResult(statistic=9.177594898995832, pvalue=2.4701353150852427e-19)],
#   ['Node38',
#    Ttest_indResult(statistic=10.580462523461815, pvalue=7.196201150946155e-25)],
#   ['Node39',
#    Ttest_indResult(statistic=-17.17120473736834, pvalue=4.220406784463223e-58)],
#   ['Node40',
#    Ttest_indResult(statistic=-2.298464479961573, pvalue=0.02174133553402723)],
#   ['Node41',
#    Ttest_indResult(statistic=-9.073519987369814, pvalue=5.996255770724252e-19)],
#   ['Node42',
#    Ttest_indResult(statistic=12.03167742813608, pvalue=3.1211452999552454e-31)],
#   ['Node43',
#    Ttest_indResult(statistic=-0.632356975945674, pvalue=0.527298482243375)],
#   ['Node44',
#    Ttest_indResult(statistic=-5.530492737008448, pvalue=4.0780847004622074e-08)],
#   ['Node45',
#    Ttest_indResult(statistic=-4.83605521993491, pvalue=1.5330782193446953e-06)],
#   ['Node46',
#    Ttest_indResult(statistic=4.965002388425556, pvalue=8.076378083300619e-07)],
#   ['Node47',
#    Ttest_indResult(statistic=4.059350440184566, pvalue=5.3058051285683544e-05)],
#   ['Node48',
#    Ttest_indResult(statistic=3.6133453909043776, pvalue=0.0003173500547501171)],
#   ['Node49', Ttest_indResult(statistic=0.0, pvalue=1.0)],
#   ['Node50',
#    Ttest_indResult(statistic=-7.8863474912058535, pvalue=8.130739363904302e-15)],
#   ['Node51',
#    Ttest_indResult(statistic=35.78802316461529, pvalue=3.975918306890181e-181)],
#   ['Node52',
#    Ttest_indResult(statistic=-57.277886756578255, pvalue=9.965225e-318)],
#   ['Node53',
#    Ttest_indResult(statistic=-1.4400599321662162, pvalue=0.15016405325431367)],
#   ['Node54',
#    Ttest_indResult(statistic=-1.6218982894507585, pvalue=0.10514097612627467)],
#   ['Node55',
#    Ttest_indResult(statistic=8.907146438479872, pvalue=2.4325060003824397e-18)],
#   ['Node56',
#    Ttest_indResult(statistic=31.45446719932891, pvalue=1.891771404288019e-151)],
#   ['Node57',
#    Ttest_indResult(statistic=-0.632356975945674, pvalue=0.527298482243375)],
#   ['Node58',
#    Ttest_indResult(statistic=28.67702428065709, pvalue=2.0919268403621013e-132)],
#   ['Node59',
#    Ttest_indResult(statistic=31.287798239425978, pvalue=2.638357237812951e-150)],
#   ['Node60',
#    Ttest_indResult(statistic=30.57280741248351, pvalue=2.1380495227179747e-145)],
#   ['Node61',
#    Ttest_indResult(statistic=2.907653966461577, pvalue=0.0037221390079673097)],
#   ['Node62', Ttest_indResult(statistic=-72.82629448988155, pvalue=0.0)],
#   ['Node63',
#    Ttest_indResult(statistic=-2.213167377354956, pvalue=0.027111712387466985)],
#   ['Node64',
#    Ttest_indResult(statistic=0.9117448856942347, pvalue=0.3621232032908951)],
#   ['Node65',
#    Ttest_indResult(statistic=6.8381781593841415, pvalue=1.3955980404088215e-11)],
#   ['Node66',
#    Ttest_indResult(statistic=19.461306929353444, pvalue=9.120564303052067e-72)],
#   ['Node67',
#    Ttest_indResult(statistic=-0.632356975945674, pvalue=0.527298482243375)],
#   ['Node68',
#    Ttest_indResult(statistic=8.653584482401168, pvalue=1.972159306937514e-17)],
#   ['Node69',
#    Ttest_indResult(statistic=0.0868629538566518, pvalue=0.9307978710239215)],
#   ['Node70',
#    Ttest_indResult(statistic=1.4592537717140612, pvalue=0.1448099408865428)],
#   ['Node71',
#    Ttest_indResult(statistic=3.427708844353039, pvalue=0.00063355036154717)],
#   ['Node72',
#    Ttest_indResult(statistic=-0.9371131128298901, pvalue=0.34892709216449636)],
#   ['Node73',
#    Ttest_indResult(statistic=3.268594849285065, pvalue=0.0011177345346500935)],
#   ['Node74',
#    Ttest_indResult(statistic=3.9440218243682943, pvalue=8.572677306129624e-05)],
#   ['Node75',
#    Ttest_indResult(statistic=16.592783789131648, pvalue=8.61930111519297e-55)],
#   ['Node76',
#    Ttest_indResult(statistic=-17.80507933827389, pvalue=8.483696591304544e-62)],
#   ['Node77',
#    Ttest_indResult(statistic=-2.7769516330280735, pvalue=0.005589886350225301)],
#   ['Node78',
#    Ttest_indResult(statistic=-6.3432069263541795, pvalue=3.406177598686804e-10)],
#   ['Node79',
#    Ttest_indResult(statistic=10.638220962187512, pvalue=4.1291915477150566e-25)],
#   ['Node80',
#    Ttest_indResult(statistic=1.3958886725269615, pvalue=0.1630584670091783)],
#   ['Node81',
#    Ttest_indResult(statistic=8.323789289432886, pvalue=2.7807530430313594e-16)],
#   ['Node82',
#    Ttest_indResult(statistic=6.6036736325458305, pvalue=6.50866064862594e-11)],
#   ['Node83',
#    Ttest_indResult(statistic=26.42695908000222, pvalue=4.245430387560426e-117)],
#   ['Node84',
#    Ttest_indResult(statistic=6.340031452854417, pvalue=3.4743500444995273e-10)],
#   ['Node85',
#    Ttest_indResult(statistic=2.5279230996212703, pvalue=0.011627287634912518)],
#   ['Node86',
#    Ttest_indResult(statistic=0.7556009637469373, pvalue=0.4500667714894504)],
#   ['Node87',
#    Ttest_indResult(statistic=-7.128531984678523, pvalue=1.9438486135883694e-12)],
#   ['Node88',
#    Ttest_indResult(statistic=34.52717707774203, pvalue=1.6070879864047743e-172)],
#   ['Node89',
#    Ttest_indResult(statistic=-50.076353025277996, pvalue=1.5922966158159147e-274)],
#   ['Node90',
#    Ttest_indResult(statistic=0.6848471171017612, pvalue=0.4935994162928755)],
#   ['Node91',
#    Ttest_indResult(statistic=-2.204761697579777, pvalue=0.027698331980062472)],
#   ['Node92',
#    Ttest_indResult(statistic=7.742988649314536, pvalue=2.3761832904743906e-14)],
#   ['Node93',
#    Ttest_indResult(statistic=33.03816324891219, pvalue=2.545503578222532e-162)],
#   ['Node94',
#    Ttest_indResult(statistic=-1.6218982894507585, pvalue=0.10514097612627467)],
#   ['Node95',
#    Ttest_indResult(statistic=28.756803507210677, pvalue=5.957851767094279e-133)],
#   ['Node96',
#    Ttest_indResult(statistic=41.6459276498583, pvalue=1.7083863791806228e-220)],
#   ['Node97',
#    Ttest_indResult(statistic=29.394584659396823, pvalue=2.5699941028919217e-137)],
#   ['Node98',
#    Ttest_indResult(statistic=1.9866632113040346, pvalue=0.04723284883696781)],
#   ['Node99', Ttest_indResult(statistic=-62.80039225731679, pvalue=0.0)],
#   ['Node100',
#    Ttest_indResult(statistic=-3.951671746440136, pvalue=8.307250014582244e-05)],
#   ['Node102',
#    Ttest_indResult(statistic=6.501840038056274, pvalue=1.251773680017712e-10)],
#   ['Node103',
#    Ttest_indResult(statistic=30.53120862664752, pvalue=4.125980625016752e-145)],
#   ['Node104',
#    Ttest_indResult(statistic=-1.3551510126259223, pvalue=0.17567608468817447)],
#   ['Node105',
#    Ttest_indResult(statistic=9.692708631382159, pvalue=2.714370069133969e-21)],
#   ['Node106',
#    Ttest_indResult(statistic=-3.4491576858302486, pvalue=0.0005858457565824692)],
#   ['Node107',
#    Ttest_indResult(statistic=-1.509196844842014, pvalue=0.13156499522196383)],
#   ['Node108',
#    Ttest_indResult(statistic=4.327667248230513, pvalue=1.6586518844788337e-05)],
#   ['Node109',
#    Ttest_indResult(statistic=-4.975585616926513, pvalue=7.657453296358407e-07)],
#   ['Node110',
#    Ttest_indResult(statistic=1.548928940610794, pvalue=0.12171583693307571)],
#   ['Node111',
#    Ttest_indResult(statistic=7.489795884944849, pvalue=1.515477156855865e-13)],
#   ['Node112',
#    Ttest_indResult(statistic=16.95302557683949, pvalue=7.607086414973673e-57)],
#   ['Node113',
#    Ttest_indResult(statistic=-15.1088677971793, pvalue=1.335767410780427e-46)],
#   ['Node114',
#    Ttest_indResult(statistic=-2.8184244882468605, pvalue=0.004921365857111734)],
#   ['Node115',
#    Ttest_indResult(statistic=-5.921427809000714, pvalue=4.386471394237104e-09)],
#   ['Node116',
#    Ttest_indResult(statistic=10.787517332086011, pvalue=9.717884152059947e-26)],
#   ['Node117',
#    Ttest_indResult(statistic=-0.8617990916789168, pvalue=0.38900510165705515)],
#   ['Node118',
#    Ttest_indResult(statistic=-4.498626548704856, pvalue=7.642975744195234e-06)],
#   ['Node119',
#    Ttest_indResult(statistic=-4.959344952669591, pvalue=8.309301652126077e-07)],
#   ['Node120',
#    Ttest_indResult(statistic=4.157528531669751, pvalue=3.493427645930728e-05)],
#   ['Node121',
#    Ttest_indResult(statistic=4.421141024086916, pvalue=1.0894151274594055e-05)],
#   ['Node122',
#    Ttest_indResult(statistic=2.656772591879677, pvalue=0.008015194823777499)],
#   ['Node123',
#    Ttest_indResult(statistic=-0.6866924779816574, pvalue=0.4924360559677181)],
#   ['Node124',
#    Ttest_indResult(statistic=-7.377941786380673, pvalue=3.3782797702174244e-13)],
#   ['Node125',
#    Ttest_indResult(statistic=35.05730590890431, pvalue=3.831057004053793e-176)],
#   ['Node126',
#    Ttest_indResult(statistic=-49.50438606039715, pvalue=5.666954847231595e-271)],
#   ['Node127',
#    Ttest_indResult(statistic=-1.103944355881398, pvalue=0.26988337513769955)],
#   ['Node128',
#    Ttest_indResult(statistic=-1.9043681930901688, pvalue=0.05714957174394456)],
#   ['Node129',
#    Ttest_indResult(statistic=7.9717692487411895, pvalue=4.257410104161508e-15)],
#   ['Node130',
#    Ttest_indResult(statistic=35.51101798200956, pvalue=3.0715240355562795e-179)],
#   ['Node131',
#    Ttest_indResult(statistic=0.7409658525996637, pvalue=0.45888844661831585)],
#   ['Node132',
#    Ttest_indResult(statistic=28.235331811662142, pvalue=2.176331072100842e-129)],
#   ['Node133',
#    Ttest_indResult(statistic=33.31241261244898, pvalue=3.349628265324262e-164)],
#   ['Node134',
#    Ttest_indResult(statistic=34.769230324544466, pvalue=3.558450744564897e-174)],
#   ['Node135',
#    Ttest_indResult(statistic=1.548928940610794, pvalue=0.12171583693307571)],
#   ['Node136', Ttest_indResult(statistic=-84.7638133892387, pvalue=0.0)],
#   ['Node137',
#    Ttest_indResult(statistic=-2.378300603593231, pvalue=0.017580044373354285)],
#   ['Node138',
#    Ttest_indResult(statistic=1.6982519384012702, pvalue=0.08977193428547735)],
#   ['Node139',
#    Ttest_indResult(statistic=8.040942743865164, pvalue=2.5102723810673115e-15)],
#   ['Node140',
#    Ttest_indResult(statistic=29.017209458407944, pvalue=9.856788391593115e-135)],
#   ['Node141',
#    Ttest_indResult(statistic=-0.8617990916789168, pvalue=0.38900510165705515)],
#   ['Node142',
#    Ttest_indResult(statistic=9.028875996319972, pvalue=8.749594762933378e-19)],
#   ['Node143',
#    Ttest_indResult(statistic=-3.6920853572623638, pvalue=0.00023447193051717445)],
#   ['Node144',
#    Ttest_indResult(statistic=-1.533613164608669, pvalue=0.12544177779076027)],
#   ['Node145',
#    Ttest_indResult(statistic=3.6542271421748618, pvalue=0.00027139108433452873)],
#   ['Node146',
#    Ttest_indResult(statistic=-4.617862769154784, pvalue=4.3832912114841475e-06)],
#   ['Node147',
#    Ttest_indResult(statistic=1.9866632113040346, pvalue=0.04723284883696781)],
#   ['Node148',
#    Ttest_indResult(statistic=7.80665668211383, pvalue=1.4788832657957505e-14)],
#   ['Node149',
#    Ttest_indResult(statistic=19.253925707219924, pvalue=1.701744115659456e-70)],
#   ['Node150',
#    Ttest_indResult(statistic=-14.63633886779533, pvalue=4.317095527793688e-44)],
#   ['Node151',
#    Ttest_indResult(statistic=-3.2142548220419083, pvalue=0.0013497793281199504)],
#   ['Node152',
#    Ttest_indResult(statistic=-4.810410022988094, pvalue=1.7384045420302976e-06)],
#   ['Node153',
#    Ttest_indResult(statistic=8.316892613930245, pvalue=2.936255093441459e-16)],
#   ['Node154',
#    Ttest_indResult(statistic=4.468482314019338, pvalue=8.778610002549415e-06)],
#   ['Node155',
#    Ttest_indResult(statistic=-4.040359060534318, pvalue=5.7467578960639085e-05)],
#   ['Node156',
#    Ttest_indResult(statistic=-5.430847486598841, pvalue=7.045554095479099e-08)],
#   ['Node157',
#    Ttest_indResult(statistic=4.05143042312499, pvalue=5.485645116658906e-05)],
#   ['Node158',
#    Ttest_indResult(statistic=5.995559848132996, pvalue=2.8308808221670966e-09)],
#   ['Node159',
#    Ttest_indResult(statistic=2.2627620592870605, pvalue=0.023864598268239133)],
#   ['Node160',
#    Ttest_indResult(statistic=0.4187001872275972, pvalue=0.6755253483174155)],
#   ['Node161',
#    Ttest_indResult(statistic=-7.934467023695718, pvalue=5.651501374337589e-15)],
#   ['Node162',
#    Ttest_indResult(statistic=34.35371622962723, pvalue=2.4691093267059368e-171)],
#   ['Node163',
#    Ttest_indResult(statistic=-46.69952462478573, pvalue=2.6156650566544094e-253)],
#   ['Node164',
#    Ttest_indResult(statistic=0.8285528982666237, pvalue=0.40755555292603307)],
#   ['Node165',
#    Ttest_indResult(statistic=-1.1022966718011429, pvalue=0.2705984649037418)],
#   ['Node166',
#    Ttest_indResult(statistic=8.192476324481467, pvalue=7.785059549786162e-16)],
#   ['Node167',
#    Ttest_indResult(statistic=35.117224741683174, pvalue=1.493491492660909e-176)],
#   ['Node168',
#    Ttest_indResult(statistic=-1.3551510126259223, pvalue=0.17567608468817447)],
#   ['Node169',
#    Ttest_indResult(statistic=28.502982067266146, pvalue=3.235826115143742e-131)],
#   ['Node170',
#    Ttest_indResult(statistic=37.57588325004629, pvalue=2.900385540237135e-193)],
#   ['Node171',
#    Ttest_indResult(statistic=28.149492849606567, pvalue=8.385184295780801e-129)],
#   ['Node172',
#    Ttest_indResult(statistic=-1.1022966718011429, pvalue=0.2705984649037418)],
#   ['Node173', Ttest_indResult(statistic=-80.63351604591162, pvalue=0.0)],
#   ['Node174',
#    Ttest_indResult(statistic=-2.8526675839082403, pvalue=0.004424920789119062)],
#   ['Node175',
#    Ttest_indResult(statistic=2.1261602694268382, pvalue=0.033734855458362904)],
#   ['Node176',
#    Ttest_indResult(statistic=6.069654553312791, pvalue=1.8186167677923781e-09)],
#   ['Node177',
#    Ttest_indResult(statistic=36.69770387202689, pvalue=2.587931735635096e-187)],
#   ['Node178',
#    Ttest_indResult(statistic=-0.41285906143797246, pvalue=0.6797985572693879)],
#   ['Node179',
#    Ttest_indResult(statistic=8.501930963717022, pvalue=6.730613202419304e-17)],
#   ['Node180',
#    Ttest_indResult(statistic=-5.283733244446586, pvalue=1.5541999914262862e-07)],
#   ['Node181',
#    Ttest_indResult(statistic=-3.3048034446507493, pvalue=0.0009842508598315073)],
#   ['Node182',
#    Ttest_indResult(statistic=5.373970761029751, pvalue=9.588316778506696e-08)],
#   ['Node183',
#    Ttest_indResult(statistic=-6.601623538623743, pvalue=6.595501922285972e-11)],
#   ['Node184',
#    Ttest_indResult(statistic=1.9866632113040346, pvalue=0.04723284883696781)],
#   ['Node185',
#    Ttest_indResult(statistic=9.54632504882956, pvalue=9.9823985682256e-21)],
#   ['Node186',
#    Ttest_indResult(statistic=23.07961588065546, pvalue=8.731582700681377e-95)],
#   ['Node187',
#    Ttest_indResult(statistic=-15.602589991715554, pvalue=2.8270021880304043e-49)],
#   ['Node188',
#    Ttest_indResult(statistic=-3.075535702714751, pvalue=0.0021584476115433858)],
#   ['Node189',
#    Ttest_indResult(statistic=-5.050298230138045, pvalue=5.242564425043648e-07)],
#   ['Node190',
#    Ttest_indResult(statistic=12.017424332911231, pvalue=3.6288590691074694e-31)],
#   ['Node191',
#    Ttest_indResult(statistic=-1.3551510126259223, pvalue=0.17567608468817447)],
#   ['Node192',
#    Ttest_indResult(statistic=-4.582561135344803, pvalue=5.174497498713258e-06)],
#   ['Node193',
#    Ttest_indResult(statistic=-4.255615468019615, pvalue=2.2810741393223384e-05)],
#   ['Node194',
#    Ttest_indResult(statistic=4.36600515855653, pvalue=1.3973093518135388e-05)],
#   ['Node195',
#    Ttest_indResult(statistic=5.124918644696653, pvalue=3.5730944198305246e-07)],
#   ['Node196',
#    Ttest_indResult(statistic=3.6133453909043776, pvalue=0.0003173500547501171)],
#   ['Node197',
#    Ttest_indResult(statistic=1.3674536052048738, pvalue=0.17179104503303122)],
#   ['Node198',
#    Ttest_indResult(statistic=-7.2811820904965305, pvalue=6.70210475378872e-13)],
#   ['Node199',
#    Ttest_indResult(statistic=36.547960169002025, pvalue=2.6904218695255094e-186)],
#   ['Node200',
#    Ttest_indResult(statistic=-55.68484077344783, pvalue=2.056231333564137e-308)],
#   ['Node201',
#    Ttest_indResult(statistic=-1.0701543345495728, pvalue=0.2848085909988475)],
#   ['Node202',
#    Ttest_indResult(statistic=-1.3551510126259223, pvalue=0.17567608468817447)],
#   ['Node203',
#    Ttest_indResult(statistic=6.6786149770605965, pvalue=3.999446670467135e-11)],
#   ['Node204',
#    Ttest_indResult(statistic=36.82328577875775, pvalue=3.636143608143813e-188)],
#   ['Node205',
#    Ttest_indResult(statistic=-2.8706474698943008, pvalue=0.004182871272450809)],
#   ['Node206',
#    Ttest_indResult(statistic=35.15868175111545, pvalue=7.783677382120061e-177)],
#   ['Node207',
#    Ttest_indResult(statistic=37.4795934788964, pvalue=1.2995195176827162e-192)],
#   ['Node208',
#    Ttest_indResult(statistic=28.360818036114907, pvalue=3.027088431135118e-130)],
#   ['Node209',
#    Ttest_indResult(statistic=2.2627620592870605, pvalue=0.023864598268239133)],
#   ['Node210', Ttest_indResult(statistic=-66.580628742686, pvalue=0.0)],
#   ['Node211',
#    Ttest_indResult(statistic=-0.34561457069712354, pvalue=0.7297052305554976)],
#   ['Node212',
#    Ttest_indResult(statistic=1.3958886725269612, pvalue=0.1630584670091784)],
#   ['Node213',
#    Ttest_indResult(statistic=5.892667276807297, pvalue=5.192081379080141e-09)],
#   ['Node214',
#    Ttest_indResult(statistic=43.619483475466, pvalue=1.878796039470227e-233)],
#   ['Node215',
#    Ttest_indResult(statistic=-1.3551510126259223, pvalue=0.17567608468817447)],
#   ['Node216',
#    Ttest_indResult(statistic=9.983806952382167, pvalue=1.942732178920386e-22)],
#   ['Node217',
#    Ttest_indResult(statistic=-4.435828015177034, pvalue=1.0190540105098486e-05)],
#   ['Node218',
#    Ttest_indResult(statistic=-2.8228636511986815, pvalue=0.0048542801649928795)],
#   ['Node219',
#    Ttest_indResult(statistic=4.642432928625834, pvalue=3.902592071778255e-06)],
#   ['Node220',
#    Ttest_indResult(statistic=-5.2453288136038285, pvalue=1.904704922585738e-07)],
#   ['Node221',
#    Ttest_indResult(statistic=3.1501972880720888, pvalue=0.0016801498995579367)],
#   ['Node222',
#    Ttest_indResult(statistic=9.251679807683702, pvalue=1.307221946104121e-19)],
#   ['Node223',
#    Ttest_indResult(statistic=21.325104411836328, pvalue=1.9271227915198707e-83)],
#   ['Node224',
#    Ttest_indResult(statistic=-16.904931325390717, pvalue=1.4350867300976115e-56)],
#   ['Node225',
#    Ttest_indResult(statistic=-2.29186203313973, pvalue=0.022121106717123678)],
#   ['Node226',
#    Ttest_indResult(statistic=-5.58161046947254, pvalue=3.070156362633959e-08)],
#   ['Node227',
#    Ttest_indResult(statistic=12.627353522944132, pvalue=5.111398685247494e-34)],
#   ['Node228',
#    Ttest_indResult(statistic=1.9866632113040346, pvalue=0.04723284883696781)],
#   ['Node229',
#    Ttest_indResult(statistic=-2.6588551514116374, pvalue=0.007966174275401264)],
#   ['Node230',
#    Ttest_indResult(statistic=-2.4940976146177154, pvalue=0.012788662724004515)],
#   ['Node231',
#    Ttest_indResult(statistic=4.157528531669751, pvalue=3.493427645930728e-05)],
#   ['Node232',
#    Ttest_indResult(statistic=5.565518924139601, pvalue=3.358005109625474e-08)],
#   ['Node233',
#    Ttest_indResult(statistic=0.5648684595144029, pvalue=0.572290181113797)],
#   ['Node234',
#    Ttest_indResult(statistic=3.339189889541656, pvalue=0.0008713154595588263)],
#   ['Node235',
#    Ttest_indResult(statistic=-4.8739093070721315, pvalue=1.2721042724615782e-06)],
#   ['Node236',
#    Ttest_indResult(statistic=40.63624025047059, pvalue=8.472836458717165e-214)],
#   ['Node237', Ttest_indResult(statistic=-59.53279705669892, pvalue=0.0)],
#   ['Node238',
#    Ttest_indResult(statistic=-0.8968399073387062, pvalue=0.3700206324016576)],
#   ['Node239',
#    Ttest_indResult(statistic=-2.8706474698943008, pvalue=0.004182871272450809)],
#   ['Node240',
#    Ttest_indResult(statistic=7.3270401419249325, pvalue=4.848755777495981e-13)],
#   ['Node241',
#    Ttest_indResult(statistic=43.1197528230383, pvalue=3.455563509736857e-230)],
#   ['Node242',
#    Ttest_indResult(statistic=-0.20234937496696168, pvalue=0.8396848438599205)],
#   ['Node243',
#    Ttest_indResult(statistic=37.0850067084703, pvalue=6.106751547174992e-190)],
#   ['Node244',
#    Ttest_indResult(statistic=48.368180473107046, pvalue=7.2342936457660835e-264)],
#   ['Node245',
#    Ttest_indResult(statistic=32.75198664665361, pvalue=2.339483471215844e-160)],
#   ['Node246',
#    Ttest_indResult(statistic=4.262369872645609, pvalue=2.2143857963536063e-05)],
#   ['Node247', Ttest_indResult(statistic=-70.7377148587389, pvalue=0.0)],
#   ['Node248',
#    Ttest_indResult(statistic=-2.87531835129639, pvalue=0.0041219911385904084)],
#   ['Node249',
#    Ttest_indResult(statistic=0.9117448856942347, pvalue=0.3621232032908951)],
#   ['Node250',
#    Ttest_indResult(statistic=6.244215956194043, pvalue=6.291795815175571e-10)],
#   ['Node251',
#    Ttest_indResult(statistic=36.69770387202689, pvalue=2.587931735635096e-187)],
#   ['Node252',
#    Ttest_indResult(statistic=-1.6218982894507585, pvalue=0.10514097612627467)],
#   ['Node253',
#    Ttest_indResult(statistic=9.619590621353915, pvalue=5.2124044480920446e-21)],
#   ['Node254',
#    Ttest_indResult(statistic=-4.986216806076118, pvalue=7.257773771200119e-07)],
#   ['Node255',
#    Ttest_indResult(statistic=-2.6955431532053615, pvalue=0.007145573347668663)],
#   ['Node256',
#    Ttest_indResult(statistic=5.298634826561938, pvalue=1.4357655232933946e-07)],
#   ['Node257',
#    Ttest_indResult(statistic=-6.330028410027391, pvalue=3.697936442794195e-10)],
#   ['Node258',
#    Ttest_indResult(statistic=0.38301434085501673, pvalue=0.7017906947720274)],
#   ['Node259',
#    Ttest_indResult(statistic=9.911228492876848, pvalue=3.7713780176283043e-22)],
#   ['Node260',
#    Ttest_indResult(statistic=18.13049848248168, pvalue=1.0093423024133024e-63)],
#   ['Node261',
#    Ttest_indResult(statistic=-17.227974917293423, pvalue=1.982260112436882e-58)],
#   ['Node262',
#    Ttest_indResult(statistic=-3.6614164129819704, pvalue=0.00026398510907262366)],
#   ['Node263',
#    Ttest_indResult(statistic=-7.371834369161639, pvalue=3.5283761466942376e-13)],
#   ['Node264',
#    Ttest_indResult(statistic=15.067293994761332, pvalue=2.231082384879376e-46)],
#   ['Node265',
#    Ttest_indResult(statistic=-0.8617990916789168, pvalue=0.38900510165705515)],
#   ['Node266',
#    Ttest_indResult(statistic=-4.355560178471281, pvalue=1.4643223485416873e-05)],
#   ['Node267',
#    Ttest_indResult(statistic=-2.129257178031174, pvalue=0.033477256851942125)],
#   ['Node268',
#    Ttest_indResult(statistic=3.725041721763257, pvalue=0.00020622883420561618)],
#   ['Node269',
#    Ttest_indResult(statistic=5.548674475003206, pvalue=3.687371207083125e-08)],
#   ['Node270',
#    Ttest_indResult(statistic=4.05143042312499, pvalue=5.485645116658906e-05)],
#   ['Node271',
#    Ttest_indResult(statistic=3.5168714115519095, pvalue=0.0004563151236842785)],
#   ['Node272',
#    Ttest_indResult(statistic=-4.390018627123725, pvalue=1.2541755216768553e-05)],
#   ['Node273',
#    Ttest_indResult(statistic=41.1212728687369, pvalue=5.085844454486498e-217)],
#   ['Node274',
#    Ttest_indResult(statistic=-57.16342676371358, pvalue=4.60416e-317)],
#   ['Node275',
#    Ttest_indResult(statistic=-0.5640878931430121, pvalue=0.5728210557549628)],
#   ['Node276',
#    Ttest_indResult(statistic=-1.9043681930901688, pvalue=0.05714957174394456)],
#   ['Node277',
#    Ttest_indResult(statistic=8.61583986176887, pvalue=2.6814150975471132e-17)],
#   ['Node278',
#    Ttest_indResult(statistic=34.52298541973119, pvalue=1.7167420532153943e-172)],
#   ['Node279',
#    Ttest_indResult(statistic=-2.204761697579777, pvalue=0.027698331980062472)],
#   ['Node280',
#    Ttest_indResult(statistic=30.261861732368022, pvalue=2.9096414223444744e-143)],
#   ['Node281',
#    Ttest_indResult(statistic=29.510968081918993, pvalue=4.098203496458274e-138)],
#   ['Node282',
#    Ttest_indResult(statistic=36.75856209428486, pvalue=9.996752893468581e-188)],
#   ['Node283',
#    Ttest_indResult(statistic=10.703588632264577, pvalue=2.195895369684119e-25)],
#   ['Node284', Ttest_indResult(statistic=-66.78157452150197, pvalue=0.0)],
#   ['Node285',
#    Ttest_indResult(statistic=-1.1416826479417272, pvalue=0.2538598088339714)],
#   ['Node286',
#    Ttest_indResult(statistic=0.9117448856942347, pvalue=0.3621232032908951)],
#   ['Node287',
#    Ttest_indResult(statistic=5.438463691308984, pvalue=6.75927582203083e-08)],
#   ['Node288',
#    Ttest_indResult(statistic=34.81191522236622, pvalue=1.8178706390706275e-174)],
#   ['Node289',
#    Ttest_indResult(statistic=-1.6218982894507585, pvalue=0.10514097612627467)],
#   ['Node290',
#    Ttest_indResult(statistic=2.396632671237523, pvalue=0.016729656621397714)],
#   ['Node291',
#    Ttest_indResult(statistic=-3.488939099659594, pvalue=0.0005061135345866296)],
#   ['Node292',
#    Ttest_indResult(statistic=-2.0643023586190146, pvalue=0.039247020651235386)],
#   ['Node293',
#    Ttest_indResult(statistic=6.334173593407227, pvalue=3.603626941588789e-10)],
#   ['Node294',
#    Ttest_indResult(statistic=-4.6827241076626045, pvalue=3.2219389334998165e-06)],
#   ['Node295',
#    Ttest_indResult(statistic=4.262369872645609, pvalue=2.2143857963536063e-05)],
#   ['Node296',
#    Ttest_indResult(statistic=8.501930963717022, pvalue=6.730613202419304e-17)],
#   ['Node297',
#    Ttest_indResult(statistic=9.570418817926816, pvalue=8.06540349570259e-21)],
#   ['Node298',
#    Ttest_indResult(statistic=-16.170682875466497, pvalue=2.0454869316872625e-52)],
#   ['Node299',
#    Ttest_indResult(statistic=-2.9549616723400765, pvalue=0.003200536915079778)],
#   ['Node300',
#    Ttest_indResult(statistic=-9.067007330057525, pvalue=6.336679908048686e-19)],
#   ['Node301',
#    Ttest_indResult(statistic=10.082535053512103, pvalue=7.831333826501399e-23)],
#   ['Node302',
#    Ttest_indResult(statistic=1.2388730170581264, pvalue=0.21568381765871436)],
#   ['Node303',
#    Ttest_indResult(statistic=-4.233091912572263, pvalue=2.51756455079549e-05)],
#   ['Node304',
#    Ttest_indResult(statistic=-3.8796027180622508, pvalue=0.00011148739364737607)],
#   ['Node305',
#    Ttest_indResult(statistic=6.670979134599139, pvalue=4.203823322850596e-11)],
#   ['Node306',
#    Ttest_indResult(statistic=6.116947602511977, pvalue=1.3676977382401923e-09)],
#   ['Node307',
#    Ttest_indResult(statistic=1.844092152240028, pvalue=0.06546597200902775)],
#   ['Node308',
#    Ttest_indResult(statistic=1.7503785158741842, pvalue=0.08036029419259666)],
#   ['Node309',
#    Ttest_indResult(statistic=-9.073519987369815, pvalue=5.996255770724209e-19)],
#   ['Node310',
#    Ttest_indResult(statistic=32.86030943314549, pvalue=4.225472603362057e-161)],
#   ['Node311',
#    Ttest_indResult(statistic=-53.17604976139503, pvalue=1.8263555091819337e-293)],
#   ['Node312',
#    Ttest_indResult(statistic=-0.701953075161333, pvalue=0.4828720950628841)],
#   ['Node313',
#    Ttest_indResult(statistic=-1.9043681930901688, pvalue=0.05714957174394456)],
#   ['Node314',
#    Ttest_indResult(statistic=10.242694539083205, pvalue=1.7667668677581457e-23)],
#   ['Node315',
#    Ttest_indResult(statistic=27.68332885692009, pvalue=1.2620643991730823e-125)],
#   ['Node316',
#    Ttest_indResult(statistic=-2.204761697579777, pvalue=0.027698331980062472)],
#   ['Node317',
#    Ttest_indResult(statistic=22.78165919518177, pvalue=7.728716018093794e-93)],
#   ['Node318',
#    Ttest_indResult(statistic=28.858056469827552, pvalue=1.2095305185238463e-133)],
#   ['Node319',
#    Ttest_indResult(statistic=26.113969465778236, pvalue=5.521184829633168e-115)],
#   ['Node320',
#    Ttest_indResult(statistic=1.6982519384012702, pvalue=0.08977193428547735)],
#   ['Node321', Ttest_indResult(statistic=-74.20392448005774, pvalue=0.0)],
#   ['Node322',
#    Ttest_indResult(statistic=-2.8570802847248933, pvalue=0.004364366708415969)],
#   ['Node323',
#    Ttest_indResult(statistic=2.2627620592870605, pvalue=0.023864598268239133)],
#   ['Node324',
#    Ttest_indResult(statistic=8.349314030273352, pvalue=2.2727863764381735e-16)],
#   ['Node325',
#    Ttest_indResult(statistic=18.880785118543326, pvalue=3.1760865221711316e-68)],
#   ['Node326',
#    Ttest_indResult(statistic=-2.8706474698943008, pvalue=0.004182871272450809)],
#   ['Node327',
#    Ttest_indResult(statistic=10.272940155611378, pvalue=1.3309257164167596e-23)],
#   ['Node328',
#    Ttest_indResult(statistic=-6.081759016208351, pvalue=1.691017704628432e-09)],
#   ['Node329',
#    Ttest_indResult(statistic=-3.499830639456926, pvalue=0.0004861209990255386)],
#   ['Node330',
#    Ttest_indResult(statistic=6.876119606655793, pvalue=1.083057818111029e-11)],
#   ['Node331',
#    Ttest_indResult(statistic=-7.42865469706047, pvalue=2.351857396646225e-13)],
#   ['Node332',
#    Ttest_indResult(statistic=1.548928940610794, pvalue=0.12171583693307571)],
#   ['Node333',
#    Ttest_indResult(statistic=10.272940155611378, pvalue=1.3309257164167596e-23)],
#   ['Node334',
#    Ttest_indResult(statistic=19.430479137520468, pvalue=1.4103469526031357e-71)],
#   ['Node335',
#    Ttest_indResult(statistic=-17.995615898584933, pvalue=6.366131434126591e-63)],
#   ['Node336',
#    Ttest_indResult(statistic=-1.874656514232104, pvalue=0.06113188970867689)],
#   ['Node337',
#    Ttest_indResult(statistic=-5.284879600408074, pvalue=1.5447628195559298e-07)],
#   ['Node338',
#    Ttest_indResult(statistic=8.930625095097446, pvalue=1.9989084513173242e-18)],
#   ['Node339',
#    Ttest_indResult(statistic=1.548928940610794, pvalue=0.12171583693307571)],
#   ['Node340',
#    Ttest_indResult(statistic=-5.112540290993251, pvalue=3.8090216229440815e-07)],
#   ['Node341',
#    Ttest_indResult(statistic=-7.096800205831215, pvalue=2.4195065710740026e-12)],
#   ['Node342',
#    Ttest_indResult(statistic=2.783309829690156, pvalue=0.005482338426874089)],
#   ['Node343',
#    Ttest_indResult(statistic=5.298630239650395, pvalue=1.4358005973733625e-07)],
#   ['Node344',
#    Ttest_indResult(statistic=4.05143042312499, pvalue=5.485645116658906e-05)],
#   ['Node345',
#    Ttest_indResult(statistic=1.7081572065305206, pvalue=0.08791814381106476)],
#   ['Node346',
#    Ttest_indResult(statistic=-7.3025706619891, pvalue=5.764186712208183e-13)],
#   ['Node347',
#    Ttest_indResult(statistic=34.52717707774203, pvalue=1.6070879864047743e-172)],
#   ['Node348',
#    Ttest_indResult(statistic=-50.421908171074, pvalue=1.1612759123610363e-276)],
#   ['Node349',
#    Ttest_indResult(statistic=-0.3930200569356087, pvalue=0.6943886023495438)],
#   ['Node350',
#    Ttest_indResult(statistic=-3.2435542567823785, pvalue=0.0012196478750020753)],
#   ['Node351',
#    Ttest_indResult(statistic=8.19167857148957, pvalue=7.833571064299854e-16)],
#   ['Node352',
#    Ttest_indResult(statistic=38.6555715390314, pvalue=1.5125528636853672e-200)],
#   ['Node353',
#    Ttest_indResult(statistic=-1.6218982894507585, pvalue=0.10514097612627467)],
#   ['Node354',
#    Ttest_indResult(statistic=28.744073352674064, pvalue=7.280079773776835e-133)],
#   ['Node355',
#    Ttest_indResult(statistic=46.23171977472646, pvalue=2.5302608359958673e-250)],
#   ['Node356',
#    Ttest_indResult(statistic=30.025034618319722, pvalue=1.2258715216934262e-141)],
#   ['Node357',
#    Ttest_indResult(statistic=2.783309829690156, pvalue=0.005482338426874089)],
#   ['Node358', Ttest_indResult(statistic=-82.421493066248, pvalue=0.0)],
#   ['Node359',
#    Ttest_indResult(statistic=-3.287189779573043, pvalue=0.0010472205973098823)],
#   ['Node360',
#    Ttest_indResult(statistic=-1.6218982894507585, pvalue=0.10514097612627467)],
#   ['Node361',
#    Ttest_indResult(statistic=5.981474171693862, pvalue=3.0776583707554416e-09)],
#   ['Node362',
#    Ttest_indResult(statistic=35.59527017133198, pvalue=8.183675781745995e-180)],
#   ['Node363',
#    Ttest_indResult(statistic=-2.204761697579777, pvalue=0.027698331980062472)],
#   ['Node364',
#    Ttest_indResult(statistic=9.765684251358913, pvalue=1.4096944798320403e-21)],
#   ['Node365',
#    Ttest_indResult(statistic=-3.0436667265236497, pvalue=0.00239835724329242)],
#   ['Node366',
#    Ttest_indResult(statistic=-0.9096966980592932, pvalue=0.3632021271567607)],
#   ['Node367',
#    Ttest_indResult(statistic=5.785107301973401, pvalue=9.691832429785182e-09)],
#   ['Node368',
#    Ttest_indResult(statistic=-4.02011952430856, pvalue=6.254853062528076e-05)],
#   ['Node369',
#    Ttest_indResult(statistic=3.5000882875477677, pvalue=0.00048565711503156524)],
#   ['Node370',
#    Ttest_indResult(statistic=9.399329980989952, pvalue=3.6318008140114957e-20)]],
#  'supercpc_len': 21}

# %%
# %%time
print("======================================================================================")
print("T-test SVM scoring")
print("======================================================================================")
svm_PCs = Parallel(n_jobs=10)(map(delayed(CandidateSVMScore_Parallel),PCs))
# Out:
# ======================================================================================
# T-test SVM scoring
# ======================================================================================
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# ...
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# Exiting Candidate SVM Scoring function
# CPU times: user 23.6 s, sys: 0 ns, total: 23.6 s
# Wall time: 17min 30s

# %%
len(svm_PCs)
# Out:
# 3899

# %%
# logging scored results
log_directory="/home/sdelrio/alarm_datasets/log_results/mmpc_partitioned"
ff = open(log_directory+'/scored_svm_ttest_log.txt','w')
for e in sorted(svm_PCs, key=itemgetter('dataset'),reverse=True):
    ff.write(e['dataset']+';')
    ff.write(e['TargetNode']+';')
    for node in e['PC']:
        ff.write(node+'_')
    ff.write(';')
    for class_pred in e['class_precisions']:
            ff.write(class_pred[1]+'_')
            for arr_acc in class_pred[0]:
                ff.write(str(arr_acc[0])+'\t')
                ff.write(str(arr_acc[1])+'\t')
                ff.write(str(arr_acc[2])+'\t')
            ff.write('_')
    ff.write('\n')
ff.close()

# %%
# %%time
print("======================================================================================")
print("T-test NB scoring")
print("======================================================================================")
nb_PCs = Parallel(n_jobs=10)(map(delayed(CandidateNBScore_Parallel),PCs))
# Out:
# ======================================================================================
# T-test NB scoring
# ======================================================================================
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# ...
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# Exiting Candidate NB Scoring function
# CPU times: user 24 s, sys: 0 ns, total: 24 s
# Wall time: 5min 57s

# %%
# logging scored results
log_directory="/home/sdelrio/alarm_datasets/log_results/mmpc_partitioned"
ff = open(log_directory+'/scored_nb_ttest_log.txt','w')
for e in sorted(nb_PCs, key=itemgetter('dataset'),reverse=True):
    ff.write(e['dataset']+';')
    ff.write(e['TargetNode']+';')
    for node in e['PC']:
        ff.write(node+'_')
    ff.write(';')
    for class_pred in e['class_precisions']:
            ff.write(class_pred[1]+'_')
            for arr_acc in class_pred[0]:
                ff.write(str(arr_acc[0])+'\t')
                ff.write(str(arr_acc[1])+'\t')
                ff.write(str(arr_acc[2])+'\t')
            ff.write('_')
    ff.write('\n')
ff.close()

# %%
def CandidateNBScore_Parallel(PobDict):
    global files_dict

    # training and scoring
    X_train_df = files_dict[PobDict['dataset']]
    #X_train_df.columns=graph_heads
    
    #X_train, X_test, Y_train, Y_test = train_test_split(X_train_df, X_train_df[TargetEvalNode], test_size=0.1, random_state=0)
    
    X_train = X_train_df
    Y_train = X_train_df[PobDict['TargetNode']]
    
    clf = GaussianNB()
    clf.fit(X_train[PobDict['PC']],Y_train)
    
    PobDict['class_precisions']=[]
    for filename in [x for x in os.listdir(main_directory) if x.split('_')[1]==PobDict['dataset'].split('_')[1]]:
        #print(len([x for x in os.listdir(main_directory) if x.split('_')[1]==PobDict['dataset'].split('_')[1]]))
        if (filename == PobDict['dataset']):
            continue
        #print("*****")
        #print()
        #print("Testing on dataset: "+filename)
        X_test = files_dict[filename]
        #X_test.columns = graph_heads
        

        # get score values
        precision = []
        values_counter=set(X_train_df[PobDict['TargetNode']])
        for val in values_counter:
            #Y_pred_c = clf.predict(X_train_df.query( TargetEvalNode+'== '+str(i))[PobDict['supercpc']][-100:])
            if (len(X_test.query( PobDict['TargetNode']+'== '+str(val)))==0):
                precision.append([val,0,0])
                continue
            Y_pred_c = clf.predict(X_test.query( PobDict['TargetNode']+'== '+str(val))[PobDict['PC']])
            precision.append([val,len(Y_pred_c),Y_pred_c.tolist().count(val)/len(Y_pred_c)])

        #for e in range(0,len(precision)):
            #print('precision for class '+str(precision[e][0])+' with '+str(precision[e][1])+' samples in dataset : '+str(precision[e][2]))
    
        #print("G-mean score: "+str(g_mean(precision)))
        #print("*****")
        #print()
        #print(clf.score(X_test[PobDict['supercpc'][:10]],Y_test))
        PobDict['class_precisions'].append([precision,filename])
    print("Exiting Candidate NB Scoring function")
    return PobDict

# %%
def CandidateSVMScore_Parallel(PobDict):
    global files_dict
    # training and scoring
#     X_train_df = pd.read_csv(main_directory+PobDict['filename'],delimiter='  ',header=None, engine='python')
#     X_train_df.columns=graph_heads
    
    #X_train, X_test, Y_train, Y_test = train_test_split(X_train_df, X_train_df[TargetEvalNode], test_size=0.1, random_state=0)
    
    X_train = files_dict[PobDict['dataset']]
    Y_train = X_train[PobDict['TargetNode']]
    clf = LinearSVC()
    
    try:
        clf.fit(X_train[PobDict['PC']],Y_train)
    except:
        PobDict['class_precisions']=[]
        return PobDict
        
    
    
    PobDict['class_precisions']=[]
    for filename in [x for x in os.listdir(main_directory) if x.split('_')[1]==PobDict['dataset'].split('_')[1]]:
        #print(len([x for x in os.listdir(main_directory) if x.split('_')[1]==PobDict['filename'].split('_')[1]]))
        if (filename == PobDict['dataset']):
            continue
        #print("*****")
        #print()
        #print("Testing on dataset: "+filename)
#         X_test = pd.read_csv(main_directory+filename,delimiter='  ',header=None, engine='python')
        X_test = files_dict[filename]
        #X_test.columns = graph_heads
        

        # get score values
        precision = []
        values_counter=set(X_train[PobDict['TargetNode']])
        for val in values_counter:
            #Y_pred_c = clf.predict(X_train_df.query( TargetEvalNode+'== '+str(i))[PobDict['supercpc']][-100:])
            if (len(X_test.query( PobDict['TargetNode']+'== '+str(val)))==0):
                precision.append([val,0,0])
                continue
            Y_pred_c = clf.predict(X_test.query( PobDict['TargetNode']+'== '+str(val))[PobDict['PC']])
            precision.append([val,len(Y_pred_c),Y_pred_c.tolist().count(val)/len(Y_pred_c)])

        #for e in range(0,len(precision)):
            #print('precision for class '+str(precision[e][0])+' with '+str(precision[e][1])+' samples in dataset : '+str(precision[e][2]))
    
        #print("G-mean score: "+str(g_mean(precision)))
        #print("*****")
        #print()
        #print(clf.score(X_test[PobDict['supercpc'][:10]],Y_test))
        PobDict['class_precisions'].append([precision,filename])
    print("Exiting Candidate SVM Scoring function")
    return PobDict

# %%
def g_mean(precision_arr):
    counter=1
    for e in precision_arr:
        counter=counter*e[2]
    
    return counter**(1/len(precision_arr))

# %%
def balance_scoring(size1, size2):
    f_size1 = float(size1)
    f_size2 = float(size2)
    if (f_size1/f_size2 <= 1):
        return f_size1/f_size2
    else:
        return f_size2/f_size1

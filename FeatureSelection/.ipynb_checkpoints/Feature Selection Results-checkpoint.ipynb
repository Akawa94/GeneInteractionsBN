# %%
#import tensorflow as tf
import numpy as np
import pandas as pd
import scipy as sp
from scipy.stats import chi2
from math import floor
from joblib import Parallel, delayed
from sklearn.svm import LinearSVC
import random
import os
from sklearn.metrics import precision_recall_fscore_support as full_score
from sklearn.model_selection import train_test_split
import math
import matplotlib.pyplot as plt
# %load_ext pycodestyle_magic
# Out:
# The pycodestyle_magic extension is already loaded. To reload it, use:
#   %reload_ext pycodestyle_magic

# %%
log_directory="/home/a20114261/alarm_datasets/log_results/mmpc_partitioned"

# %%
#recovering results
recovery_files = ['/scored_true-mb_log.txt',
                  '/scored_entropy-mi_log.txt',
                  '/scored_ttest_log.txt',
                  '/scored_supercpc_log.txt'
                 ]
recovery_arr = []
for f_name in recovery_files:
    ff = open(log_directory+f_name,'r')
    #line_rec_scor =  ff.read().split('\n')[0].split(';')
    recovery_scored_file=[]
    for line in ff.read().split('\n'):
        line_arr=[]
        line_rec_scor=line.split(';')
        node_dict={}
        if (len(line_rec_scor[0])==0):
            continue
        node_dict['TargetNode']=line_rec_scor[1]
        node_dict['supercpc']=line_rec_scor[2].split('_')
        node_dict['class_precisions']=[]
        line_arr.append(line_rec_scor[0])

        for i in range(0,len(line_rec_scor[3].split('_')),4):
            if (len(line_rec_scor[3].split('_')[i:i+3][0])==0):
                continue
            acc_arr=[]
            acc_arr.append([float(x) for x in line_rec_scor[3].split('_')[i+3].split('\t')[:3]])
            acc_arr.append([float(x) for x in line_rec_scor[3].split('_')[i+3].split('\t')[3:6]])
            node_dict['class_precisions'].append([acc_arr,line_rec_scor[3].split('_')[i]+'_'+line_rec_scor[3].split('_')[i+1]+'_'+line_rec_scor[3].split('_')[i+2]])

        line_arr.append(node_dict)
        recovery_scored_file.append(line_arr)
    recovery_arr.append([f_name,recovery_scored_file])
    ff.close()

# %%
# recovering preselected nodes
main_directory= '/home/a20114261/alarm_datasets/Alarm10/'
save_folder='/home/a20114261/alarm_datasets/log_results/'

if not os.path.exists(main_directory):
    print("Bad routing.")
preselected_nodes=[] # will have [node_str,balance_ranking]
# so far, we need Node, size of estimated pc set per filename, balance ranking
ff = open(save_folder+'mmpc_partitioned/alarm10_binary_nodes_selected.txt','r')
for e in ff.read().split('\n'):
    spl_line = e.split(';')
    if (len(spl_line[0])==0):
        continue
    preselected_nodes.append([spl_line[0],float(spl_line[1])])
ff.close()

# %%
# processing results
sample_sizes = ['s500','s1000','s5000']

balance_ranking = []

for results_arr in recovery_arr:
    test_name = results_arr[0].split('_')[1]
    for sample_size in sample_sizes:
        bl_sorted = sorted([x for x in results_arr[1]
                               if x[0].split('_')[1] == sample_size],\
                           key=lambda x: x[1]['TargetNode'])
        evaluated_nodes = []
        
        for e in bl_sorted:
            if ('@' in e[1]['TargetNode']):
                e[1]['TargetNode']=e[1]['TargetNode'].split('@')[0]
            
            if (e[1]['TargetNode'] in evaluated_nodes) or\
                (e[1]['TargetNode'] not in [x[0].split('@')[0] for x in preselected_nodes]):
                continue
            
            print('Retrieving results from test '+test_name+', Target '+e[1]['TargetNode']+', with sample size of '+sample_size)
            evaluated_nodes.append(e[1]['TargetNode'])
            
            b_rank = [x[1] for x in preselected_nodes if x[0].split('@')[0]==e[1]['TargetNode']][0]
            g_rank = []
            for sub_e in [x for x in bl_sorted if x[1]['TargetNode'] == e[1]['TargetNode']]:
                for prec in sub_e[1]['class_precisions']:
                    g_rank.append(g_mean(prec[0]))
            balance_ranking.append([test_name,sample_size,e[1]['TargetNode'],b_rank,sum(g_rank)/len(g_rank)])
# Out:
# Retrieving results from test true-mb, Target Node101, with sample size of s500
# Retrieving results from test true-mb, Target Node102, with sample size of s500
# Retrieving results from test true-mb, Target Node104, with sample size of s500
# Retrieving results from test true-mb, Target Node105, with sample size of s500
# Retrieving results from test true-mb, Target Node11, with sample size of s500
# Retrieving results from test true-mb, Target Node110, with sample size of s500
# Retrieving results from test true-mb, Target Node111, with sample size of s500
# Retrieving results from test true-mb, Target Node117, with sample size of s500
# Retrieving results from test true-mb, Target Node120, with sample size of s500
# Retrieving results from test true-mb, Target Node122, with sample size of s500
# Retrieving results from test true-mb, Target Node125, with sample size of s500
# Retrieving results from test true-mb, Target Node128, with sample size of s500
# Retrieving results from test true-mb, Target Node131, with sample size of s500
# Retrieving results from test true-mb, Target Node135, with sample size of s500
# Retrieving results from test true-mb, Target Node138, with sample size of s500
# Retrieving results from test true-mb, Target Node139, with sample size of s500
# Retrieving results from test true-mb, Target Node14, with sample size of s500
# Retrieving results from test true-mb, Target Node141, with sample size of s500
# Retrieving results from test true-mb, Target Node142, with sample size of s500
# Retrieving results from test true-mb, Target Node147, with sample size of s500
# Retrieving results from test true-mb, Target Node148, with sample size of s500
# Retrieving results from test true-mb, Target Node154, with sample size of s500
# Retrieving results from test true-mb, Target Node157, with sample size of s500
# Retrieving results from test true-mb, Target Node159, with sample size of s500
# Retrieving results from test true-mb, Target Node162, with sample size of s500
# Retrieving results from test true-mb, Target Node165, with sample size of s500
# Retrieving results from test true-mb, Target Node168, with sample size of s500
# Retrieving results from test true-mb, Target Node17, with sample size of s500
# Retrieving results from test true-mb, Target Node172, with sample size of s500
# Retrieving results from test true-mb, Target Node175, with sample size of s500
# Retrieving results from test true-mb, Target Node176, with sample size of s500
# Retrieving results from test true-mb, Target Node178, with sample size of s500
# Retrieving results from test true-mb, Target Node179, with sample size of s500
# Retrieving results from test true-mb, Target Node184, with sample size of s500
# Retrieving results from test true-mb, Target Node185, with sample size of s500
# Retrieving results from test true-mb, Target Node191, with sample size of s500
# Retrieving results from test true-mb, Target Node194, with sample size of s500
# Retrieving results from test true-mb, Target Node196, with sample size of s500
# Retrieving results from test true-mb, Target Node199, with sample size of s500
# Retrieving results from test true-mb, Target Node20, with sample size of s500
# Retrieving results from test true-mb, Target Node202, with sample size of s500
# Retrieving results from test true-mb, Target Node205, with sample size of s500
# Retrieving results from test true-mb, Target Node209, with sample size of s500
# Retrieving results from test true-mb, Target Node212, with sample size of s500
# Retrieving results from test true-mb, Target Node213, with sample size of s500
# Retrieving results from test true-mb, Target Node215, with sample size of s500
# Retrieving results from test true-mb, Target Node216, with sample size of s500
# Retrieving results from test true-mb, Target Node221, with sample size of s500
# Retrieving results from test true-mb, Target Node222, with sample size of s500
# Retrieving results from test true-mb, Target Node228, with sample size of s500
# Retrieving results from test true-mb, Target Node231, with sample size of s500
# Retrieving results from test true-mb, Target Node233, with sample size of s500
# Retrieving results from test true-mb, Target Node236, with sample size of s500
# Retrieving results from test true-mb, Target Node239, with sample size of s500
# Retrieving results from test true-mb, Target Node24, with sample size of s500
# Retrieving results from test true-mb, Target Node242, with sample size of s500
# Retrieving results from test true-mb, Target Node246, with sample size of s500
# Retrieving results from test true-mb, Target Node249, with sample size of s500
# Retrieving results from test true-mb, Target Node250, with sample size of s500
# Retrieving results from test true-mb, Target Node252, with sample size of s500
# Retrieving results from test true-mb, Target Node253, with sample size of s500
# Retrieving results from test true-mb, Target Node258, with sample size of s500
# Retrieving results from test true-mb, Target Node259, with sample size of s500
# Retrieving results from test true-mb, Target Node265, with sample size of s500
# Retrieving results from test true-mb, Target Node268, with sample size of s500
# Retrieving results from test true-mb, Target Node27, with sample size of s500
# Retrieving results from test true-mb, Target Node270, with sample size of s500
# Retrieving results from test true-mb, Target Node273, with sample size of s500
# Retrieving results from test true-mb, Target Node276, with sample size of s500
# Retrieving results from test true-mb, Target Node279, with sample size of s500
# Retrieving results from test true-mb, Target Node28, with sample size of s500
# Retrieving results from test true-mb, Target Node283, with sample size of s500
# Retrieving results from test true-mb, Target Node286, with sample size of s500
# Retrieving results from test true-mb, Target Node287, with sample size of s500
# Retrieving results from test true-mb, Target Node289, with sample size of s500
# Retrieving results from test true-mb, Target Node290, with sample size of s500
# Retrieving results from test true-mb, Target Node295, with sample size of s500
# Retrieving results from test true-mb, Target Node296, with sample size of s500
# Retrieving results from test true-mb, Target Node30, with sample size of s500
# Retrieving results from test true-mb, Target Node302, with sample size of s500
# Retrieving results from test true-mb, Target Node305, with sample size of s500
# Retrieving results from test true-mb, Target Node307, with sample size of s500
# Retrieving results from test true-mb, Target Node31, with sample size of s500
# Retrieving results from test true-mb, Target Node310, with sample size of s500
# Retrieving results from test true-mb, Target Node313, with sample size of s500
# Retrieving results from test true-mb, Target Node316, with sample size of s500
# Retrieving results from test true-mb, Target Node320, with sample size of s500
# Retrieving results from test true-mb, Target Node323, with sample size of s500
# Retrieving results from test true-mb, Target Node324, with sample size of s500
# Retrieving results from test true-mb, Target Node326, with sample size of s500
# Retrieving results from test true-mb, Target Node327, with sample size of s500
# Retrieving results from test true-mb, Target Node332, with sample size of s500
# Retrieving results from test true-mb, Target Node333, with sample size of s500
# Retrieving results from test true-mb, Target Node339, with sample size of s500
# Retrieving results from test true-mb, Target Node342, with sample size of s500
# Retrieving results from test true-mb, Target Node344, with sample size of s500
# Retrieving results from test true-mb, Target Node347, with sample size of s500
# Retrieving results from test true-mb, Target Node350, with sample size of s500
# Retrieving results from test true-mb, Target Node353, with sample size of s500
# Retrieving results from test true-mb, Target Node357, with sample size of s500
# Retrieving results from test true-mb, Target Node36, with sample size of s500
# Retrieving results from test true-mb, Target Node360, with sample size of s500
# Retrieving results from test true-mb, Target Node361, with sample size of s500
# Retrieving results from test true-mb, Target Node363, with sample size of s500
# Retrieving results from test true-mb, Target Node364, with sample size of s500
# Retrieving results from test true-mb, Target Node369, with sample size of s500
# Retrieving results from test true-mb, Target Node37, with sample size of s500
# Retrieving results from test true-mb, Target Node370, with sample size of s500
# Retrieving results from test true-mb, Target Node43, with sample size of s500
# Retrieving results from test true-mb, Target Node46, with sample size of s500
# Retrieving results from test true-mb, Target Node48, with sample size of s500
# Retrieving results from test true-mb, Target Node51, with sample size of s500
# Retrieving results from test true-mb, Target Node54, with sample size of s500
# Retrieving results from test true-mb, Target Node57, with sample size of s500
# Retrieving results from test true-mb, Target Node6, with sample size of s500
# Retrieving results from test true-mb, Target Node61, with sample size of s500
# Retrieving results from test true-mb, Target Node64, with sample size of s500
# Retrieving results from test true-mb, Target Node65, with sample size of s500
# Retrieving results from test true-mb, Target Node67, with sample size of s500
# Retrieving results from test true-mb, Target Node68, with sample size of s500
# Retrieving results from test true-mb, Target Node73, with sample size of s500
# Retrieving results from test true-mb, Target Node74, with sample size of s500
# Retrieving results from test true-mb, Target Node80, with sample size of s500
# Retrieving results from test true-mb, Target Node83, with sample size of s500
# Retrieving results from test true-mb, Target Node85, with sample size of s500
# Retrieving results from test true-mb, Target Node88, with sample size of s500
# Retrieving results from test true-mb, Target Node9, with sample size of s500
# Retrieving results from test true-mb, Target Node91, with sample size of s500
# Retrieving results from test true-mb, Target Node94, with sample size of s500
# Retrieving results from test true-mb, Target Node98, with sample size of s500
# Retrieving results from test true-mb, Target Node101, with sample size of s1000
# Retrieving results from test true-mb, Target Node102, with sample size of s1000
# Retrieving results from test true-mb, Target Node104, with sample size of s1000
# Retrieving results from test true-mb, Target Node105, with sample size of s1000
# Retrieving results from test true-mb, Target Node11, with sample size of s1000
# Retrieving results from test true-mb, Target Node110, with sample size of s1000
# Retrieving results from test true-mb, Target Node111, with sample size of s1000
# Retrieving results from test true-mb, Target Node117, with sample size of s1000
# Retrieving results from test true-mb, Target Node120, with sample size of s1000
# Retrieving results from test true-mb, Target Node122, with sample size of s1000
# Retrieving results from test true-mb, Target Node125, with sample size of s1000
# Retrieving results from test true-mb, Target Node128, with sample size of s1000
# Retrieving results from test true-mb, Target Node131, with sample size of s1000
# Retrieving results from test true-mb, Target Node135, with sample size of s1000
# Retrieving results from test true-mb, Target Node138, with sample size of s1000
# Retrieving results from test true-mb, Target Node139, with sample size of s1000
# Retrieving results from test true-mb, Target Node14, with sample size of s1000
# Retrieving results from test true-mb, Target Node141, with sample size of s1000
# Retrieving results from test true-mb, Target Node142, with sample size of s1000
# Retrieving results from test true-mb, Target Node147, with sample size of s1000
# Retrieving results from test true-mb, Target Node148, with sample size of s1000
# Retrieving results from test true-mb, Target Node154, with sample size of s1000
# Retrieving results from test true-mb, Target Node157, with sample size of s1000
# Retrieving results from test true-mb, Target Node159, with sample size of s1000
# Retrieving results from test true-mb, Target Node162, with sample size of s1000
# Retrieving results from test true-mb, Target Node165, with sample size of s1000
# Retrieving results from test true-mb, Target Node168, with sample size of s1000
# Retrieving results from test true-mb, Target Node17, with sample size of s1000
# Retrieving results from test true-mb, Target Node172, with sample size of s1000
# Retrieving results from test true-mb, Target Node175, with sample size of s1000
# Retrieving results from test true-mb, Target Node176, with sample size of s1000
# Retrieving results from test true-mb, Target Node178, with sample size of s1000
# Retrieving results from test true-mb, Target Node179, with sample size of s1000
# Retrieving results from test true-mb, Target Node184, with sample size of s1000
# Retrieving results from test true-mb, Target Node185, with sample size of s1000
# Retrieving results from test true-mb, Target Node191, with sample size of s1000
# Retrieving results from test true-mb, Target Node194, with sample size of s1000
# Retrieving results from test true-mb, Target Node196, with sample size of s1000
# Retrieving results from test true-mb, Target Node199, with sample size of s1000
# Retrieving results from test true-mb, Target Node20, with sample size of s1000
# Retrieving results from test true-mb, Target Node202, with sample size of s1000
# Retrieving results from test true-mb, Target Node205, with sample size of s1000
# Retrieving results from test true-mb, Target Node209, with sample size of s1000
# Retrieving results from test true-mb, Target Node212, with sample size of s1000
# Retrieving results from test true-mb, Target Node213, with sample size of s1000
# Retrieving results from test true-mb, Target Node215, with sample size of s1000
# Retrieving results from test true-mb, Target Node216, with sample size of s1000
# Retrieving results from test true-mb, Target Node221, with sample size of s1000
# Retrieving results from test true-mb, Target Node222, with sample size of s1000
# Retrieving results from test true-mb, Target Node228, with sample size of s1000
# Retrieving results from test true-mb, Target Node231, with sample size of s1000
# Retrieving results from test true-mb, Target Node233, with sample size of s1000
# Retrieving results from test true-mb, Target Node236, with sample size of s1000
# Retrieving results from test true-mb, Target Node239, with sample size of s1000
# Retrieving results from test true-mb, Target Node24, with sample size of s1000
# Retrieving results from test true-mb, Target Node242, with sample size of s1000
# Retrieving results from test true-mb, Target Node246, with sample size of s1000
# Retrieving results from test true-mb, Target Node249, with sample size of s1000
# Retrieving results from test true-mb, Target Node250, with sample size of s1000
# Retrieving results from test true-mb, Target Node252, with sample size of s1000
# Retrieving results from test true-mb, Target Node253, with sample size of s1000
# Retrieving results from test true-mb, Target Node258, with sample size of s1000
# Retrieving results from test true-mb, Target Node259, with sample size of s1000
# Retrieving results from test true-mb, Target Node265, with sample size of s1000
# Retrieving results from test true-mb, Target Node268, with sample size of s1000
# Retrieving results from test true-mb, Target Node27, with sample size of s1000
# Retrieving results from test true-mb, Target Node270, with sample size of s1000
# Retrieving results from test true-mb, Target Node273, with sample size of s1000
# Retrieving results from test true-mb, Target Node276, with sample size of s1000
# Retrieving results from test true-mb, Target Node279, with sample size of s1000
# Retrieving results from test true-mb, Target Node28, with sample size of s1000
# Retrieving results from test true-mb, Target Node283, with sample size of s1000
# Retrieving results from test true-mb, Target Node286, with sample size of s1000
# Retrieving results from test true-mb, Target Node287, with sample size of s1000
# Retrieving results from test true-mb, Target Node289, with sample size of s1000
# Retrieving results from test true-mb, Target Node290, with sample size of s1000
# Retrieving results from test true-mb, Target Node295, with sample size of s1000
# Retrieving results from test true-mb, Target Node296, with sample size of s1000
# Retrieving results from test true-mb, Target Node30, with sample size of s1000
# Retrieving results from test true-mb, Target Node302, with sample size of s1000
# Retrieving results from test true-mb, Target Node305, with sample size of s1000
# Retrieving results from test true-mb, Target Node307, with sample size of s1000
# Retrieving results from test true-mb, Target Node31, with sample size of s1000
# Retrieving results from test true-mb, Target Node310, with sample size of s1000
# Retrieving results from test true-mb, Target Node313, with sample size of s1000
# Retrieving results from test true-mb, Target Node316, with sample size of s1000
# Retrieving results from test true-mb, Target Node320, with sample size of s1000
# Retrieving results from test true-mb, Target Node323, with sample size of s1000
# Retrieving results from test true-mb, Target Node324, with sample size of s1000
# Retrieving results from test true-mb, Target Node326, with sample size of s1000
# Retrieving results from test true-mb, Target Node327, with sample size of s1000
# Retrieving results from test true-mb, Target Node332, with sample size of s1000
# Retrieving results from test true-mb, Target Node333, with sample size of s1000
# Retrieving results from test true-mb, Target Node339, with sample size of s1000
# Retrieving results from test true-mb, Target Node342, with sample size of s1000
# Retrieving results from test true-mb, Target Node344, with sample size of s1000
# Retrieving results from test true-mb, Target Node347, with sample size of s1000
# Retrieving results from test true-mb, Target Node350, with sample size of s1000
# Retrieving results from test true-mb, Target Node353, with sample size of s1000
# Retrieving results from test true-mb, Target Node357, with sample size of s1000
# Retrieving results from test true-mb, Target Node36, with sample size of s1000
# Retrieving results from test true-mb, Target Node360, with sample size of s1000
# Retrieving results from test true-mb, Target Node361, with sample size of s1000
# Retrieving results from test true-mb, Target Node363, with sample size of s1000
# Retrieving results from test true-mb, Target Node364, with sample size of s1000
# Retrieving results from test true-mb, Target Node369, with sample size of s1000
# Retrieving results from test true-mb, Target Node37, with sample size of s1000
# Retrieving results from test true-mb, Target Node370, with sample size of s1000
# Retrieving results from test true-mb, Target Node43, with sample size of s1000
# Retrieving results from test true-mb, Target Node46, with sample size of s1000
# Retrieving results from test true-mb, Target Node48, with sample size of s1000
# Retrieving results from test true-mb, Target Node51, with sample size of s1000
# Retrieving results from test true-mb, Target Node54, with sample size of s1000
# Retrieving results from test true-mb, Target Node57, with sample size of s1000
# Retrieving results from test true-mb, Target Node6, with sample size of s1000
# Retrieving results from test true-mb, Target Node61, with sample size of s1000
# Retrieving results from test true-mb, Target Node64, with sample size of s1000
# Retrieving results from test true-mb, Target Node65, with sample size of s1000
# Retrieving results from test true-mb, Target Node67, with sample size of s1000
# Retrieving results from test true-mb, Target Node68, with sample size of s1000
# Retrieving results from test true-mb, Target Node73, with sample size of s1000
# Retrieving results from test true-mb, Target Node74, with sample size of s1000
# Retrieving results from test true-mb, Target Node80, with sample size of s1000
# Retrieving results from test true-mb, Target Node83, with sample size of s1000
# Retrieving results from test true-mb, Target Node85, with sample size of s1000
# Retrieving results from test true-mb, Target Node88, with sample size of s1000
# Retrieving results from test true-mb, Target Node9, with sample size of s1000
# Retrieving results from test true-mb, Target Node91, with sample size of s1000
# Retrieving results from test true-mb, Target Node94, with sample size of s1000
# Retrieving results from test true-mb, Target Node98, with sample size of s1000
# Retrieving results from test true-mb, Target Node101, with sample size of s5000
# Retrieving results from test true-mb, Target Node102, with sample size of s5000
# Retrieving results from test true-mb, Target Node104, with sample size of s5000
# Retrieving results from test true-mb, Target Node105, with sample size of s5000
# Retrieving results from test true-mb, Target Node11, with sample size of s5000
# Retrieving results from test true-mb, Target Node110, with sample size of s5000
# Retrieving results from test true-mb, Target Node111, with sample size of s5000
# Retrieving results from test true-mb, Target Node117, with sample size of s5000
# Retrieving results from test true-mb, Target Node120, with sample size of s5000
# Retrieving results from test true-mb, Target Node122, with sample size of s5000
# Retrieving results from test true-mb, Target Node125, with sample size of s5000
# Retrieving results from test true-mb, Target Node128, with sample size of s5000
# Retrieving results from test true-mb, Target Node131, with sample size of s5000
# Retrieving results from test true-mb, Target Node135, with sample size of s5000
# Retrieving results from test true-mb, Target Node138, with sample size of s5000
# Retrieving results from test true-mb, Target Node139, with sample size of s5000
# Retrieving results from test true-mb, Target Node14, with sample size of s5000
# Retrieving results from test true-mb, Target Node141, with sample size of s5000
# Retrieving results from test true-mb, Target Node142, with sample size of s5000
# Retrieving results from test true-mb, Target Node147, with sample size of s5000
# Retrieving results from test true-mb, Target Node148, with sample size of s5000
# Retrieving results from test true-mb, Target Node154, with sample size of s5000
# Retrieving results from test true-mb, Target Node157, with sample size of s5000
# Retrieving results from test true-mb, Target Node159, with sample size of s5000
# Retrieving results from test true-mb, Target Node162, with sample size of s5000
# Retrieving results from test true-mb, Target Node165, with sample size of s5000
# Retrieving results from test true-mb, Target Node168, with sample size of s5000
# Retrieving results from test true-mb, Target Node17, with sample size of s5000
# Retrieving results from test true-mb, Target Node172, with sample size of s5000
# Retrieving results from test true-mb, Target Node175, with sample size of s5000
# Retrieving results from test true-mb, Target Node176, with sample size of s5000
# Retrieving results from test true-mb, Target Node178, with sample size of s5000
# Retrieving results from test true-mb, Target Node179, with sample size of s5000
# Retrieving results from test true-mb, Target Node184, with sample size of s5000
# Retrieving results from test true-mb, Target Node185, with sample size of s5000
# Retrieving results from test true-mb, Target Node191, with sample size of s5000
# Retrieving results from test true-mb, Target Node194, with sample size of s5000
# Retrieving results from test true-mb, Target Node196, with sample size of s5000
# Retrieving results from test true-mb, Target Node199, with sample size of s5000
# Retrieving results from test true-mb, Target Node20, with sample size of s5000
# Retrieving results from test true-mb, Target Node202, with sample size of s5000
# Retrieving results from test true-mb, Target Node205, with sample size of s5000
# Retrieving results from test true-mb, Target Node209, with sample size of s5000
# Retrieving results from test true-mb, Target Node212, with sample size of s5000
# Retrieving results from test true-mb, Target Node213, with sample size of s5000
# Retrieving results from test true-mb, Target Node215, with sample size of s5000
# Retrieving results from test true-mb, Target Node216, with sample size of s5000
# Retrieving results from test true-mb, Target Node221, with sample size of s5000
# Retrieving results from test true-mb, Target Node222, with sample size of s5000
# Retrieving results from test true-mb, Target Node228, with sample size of s5000
# Retrieving results from test true-mb, Target Node231, with sample size of s5000
# Retrieving results from test true-mb, Target Node233, with sample size of s5000
# Retrieving results from test true-mb, Target Node236, with sample size of s5000
# Retrieving results from test true-mb, Target Node239, with sample size of s5000
# Retrieving results from test true-mb, Target Node24, with sample size of s5000
# Retrieving results from test true-mb, Target Node242, with sample size of s5000
# Retrieving results from test true-mb, Target Node246, with sample size of s5000
# Retrieving results from test true-mb, Target Node249, with sample size of s5000
# Retrieving results from test true-mb, Target Node250, with sample size of s5000
# Retrieving results from test true-mb, Target Node252, with sample size of s5000
# Retrieving results from test true-mb, Target Node253, with sample size of s5000
# Retrieving results from test true-mb, Target Node258, with sample size of s5000
# Retrieving results from test true-mb, Target Node259, with sample size of s5000
# Retrieving results from test true-mb, Target Node265, with sample size of s5000
# Retrieving results from test true-mb, Target Node268, with sample size of s5000
# Retrieving results from test true-mb, Target Node27, with sample size of s5000
# Retrieving results from test true-mb, Target Node270, with sample size of s5000
# Retrieving results from test true-mb, Target Node273, with sample size of s5000
# Retrieving results from test true-mb, Target Node276, with sample size of s5000
# Retrieving results from test true-mb, Target Node279, with sample size of s5000
# Retrieving results from test true-mb, Target Node28, with sample size of s5000
# Retrieving results from test true-mb, Target Node283, with sample size of s5000
# Retrieving results from test true-mb, Target Node286, with sample size of s5000
# Retrieving results from test true-mb, Target Node287, with sample size of s5000
# Retrieving results from test true-mb, Target Node289, with sample size of s5000
# Retrieving results from test true-mb, Target Node290, with sample size of s5000
# Retrieving results from test true-mb, Target Node295, with sample size of s5000
# Retrieving results from test true-mb, Target Node296, with sample size of s5000
# Retrieving results from test true-mb, Target Node30, with sample size of s5000
# Retrieving results from test true-mb, Target Node302, with sample size of s5000
# Retrieving results from test true-mb, Target Node305, with sample size of s5000
# Retrieving results from test true-mb, Target Node307, with sample size of s5000
# Retrieving results from test true-mb, Target Node31, with sample size of s5000
# Retrieving results from test true-mb, Target Node310, with sample size of s5000
# Retrieving results from test true-mb, Target Node313, with sample size of s5000
# Retrieving results from test true-mb, Target Node316, with sample size of s5000
# Retrieving results from test true-mb, Target Node320, with sample size of s5000
# Retrieving results from test true-mb, Target Node323, with sample size of s5000
# Retrieving results from test true-mb, Target Node324, with sample size of s5000
# Retrieving results from test true-mb, Target Node326, with sample size of s5000
# Retrieving results from test true-mb, Target Node327, with sample size of s5000
# Retrieving results from test true-mb, Target Node332, with sample size of s5000
# Retrieving results from test true-mb, Target Node333, with sample size of s5000
# Retrieving results from test true-mb, Target Node339, with sample size of s5000
# Retrieving results from test true-mb, Target Node342, with sample size of s5000
# Retrieving results from test true-mb, Target Node344, with sample size of s5000
# Retrieving results from test true-mb, Target Node347, with sample size of s5000
# Retrieving results from test true-mb, Target Node350, with sample size of s5000
# Retrieving results from test true-mb, Target Node353, with sample size of s5000
# Retrieving results from test true-mb, Target Node357, with sample size of s5000
# Retrieving results from test true-mb, Target Node36, with sample size of s5000
# Retrieving results from test true-mb, Target Node360, with sample size of s5000
# Retrieving results from test true-mb, Target Node361, with sample size of s5000
# Retrieving results from test true-mb, Target Node363, with sample size of s5000
# Retrieving results from test true-mb, Target Node364, with sample size of s5000
# Retrieving results from test true-mb, Target Node369, with sample size of s5000
# Retrieving results from test true-mb, Target Node37, with sample size of s5000
# Retrieving results from test true-mb, Target Node370, with sample size of s5000
# Retrieving results from test true-mb, Target Node43, with sample size of s5000
# Retrieving results from test true-mb, Target Node46, with sample size of s5000
# Retrieving results from test true-mb, Target Node48, with sample size of s5000
# Retrieving results from test true-mb, Target Node51, with sample size of s5000
# Retrieving results from test true-mb, Target Node54, with sample size of s5000
# Retrieving results from test true-mb, Target Node57, with sample size of s5000
# Retrieving results from test true-mb, Target Node6, with sample size of s5000
# Retrieving results from test true-mb, Target Node61, with sample size of s5000
# Retrieving results from test true-mb, Target Node64, with sample size of s5000
# Retrieving results from test true-mb, Target Node65, with sample size of s5000
# Retrieving results from test true-mb, Target Node67, with sample size of s5000
# Retrieving results from test true-mb, Target Node68, with sample size of s5000
# Retrieving results from test true-mb, Target Node73, with sample size of s5000
# Retrieving results from test true-mb, Target Node74, with sample size of s5000
# Retrieving results from test true-mb, Target Node80, with sample size of s5000
# Retrieving results from test true-mb, Target Node83, with sample size of s5000
# Retrieving results from test true-mb, Target Node85, with sample size of s5000
# Retrieving results from test true-mb, Target Node88, with sample size of s5000
# Retrieving results from test true-mb, Target Node9, with sample size of s5000
# Retrieving results from test true-mb, Target Node91, with sample size of s5000
# Retrieving results from test true-mb, Target Node94, with sample size of s5000
# Retrieving results from test true-mb, Target Node98, with sample size of s5000
# Retrieving results from test entropy-mi, Target Node101, with sample size of s500
# Retrieving results from test entropy-mi, Target Node102, with sample size of s500
# Retrieving results from test entropy-mi, Target Node104, with sample size of s500
# Retrieving results from test entropy-mi, Target Node105, with sample size of s500
# Retrieving results from test entropy-mi, Target Node11, with sample size of s500
# Retrieving results from test entropy-mi, Target Node110, with sample size of s500
# Retrieving results from test entropy-mi, Target Node111, with sample size of s500
# Retrieving results from test entropy-mi, Target Node117, with sample size of s500
# Retrieving results from test entropy-mi, Target Node120, with sample size of s500
# Retrieving results from test entropy-mi, Target Node122, with sample size of s500
# Retrieving results from test entropy-mi, Target Node125, with sample size of s500
# Retrieving results from test entropy-mi, Target Node128, with sample size of s500
# Retrieving results from test entropy-mi, Target Node131, with sample size of s500
# Retrieving results from test entropy-mi, Target Node135, with sample size of s500
# Retrieving results from test entropy-mi, Target Node138, with sample size of s500
# Retrieving results from test entropy-mi, Target Node139, with sample size of s500
# Retrieving results from test entropy-mi, Target Node14, with sample size of s500
# Retrieving results from test entropy-mi, Target Node141, with sample size of s500
# Retrieving results from test entropy-mi, Target Node142, with sample size of s500
# Retrieving results from test entropy-mi, Target Node147, with sample size of s500
# Retrieving results from test entropy-mi, Target Node148, with sample size of s500
# Retrieving results from test entropy-mi, Target Node154, with sample size of s500
# Retrieving results from test entropy-mi, Target Node157, with sample size of s500
# Retrieving results from test entropy-mi, Target Node159, with sample size of s500
# Retrieving results from test entropy-mi, Target Node162, with sample size of s500
# Retrieving results from test entropy-mi, Target Node165, with sample size of s500
# Retrieving results from test entropy-mi, Target Node168, with sample size of s500
# Retrieving results from test entropy-mi, Target Node17, with sample size of s500
# Retrieving results from test entropy-mi, Target Node172, with sample size of s500
# Retrieving results from test entropy-mi, Target Node175, with sample size of s500
# Retrieving results from test entropy-mi, Target Node176, with sample size of s500
# Retrieving results from test entropy-mi, Target Node178, with sample size of s500
# Retrieving results from test entropy-mi, Target Node179, with sample size of s500
# Retrieving results from test entropy-mi, Target Node184, with sample size of s500
# Retrieving results from test entropy-mi, Target Node185, with sample size of s500
# Retrieving results from test entropy-mi, Target Node191, with sample size of s500
# Retrieving results from test entropy-mi, Target Node194, with sample size of s500
# Retrieving results from test entropy-mi, Target Node196, with sample size of s500
# Retrieving results from test entropy-mi, Target Node199, with sample size of s500
# Retrieving results from test entropy-mi, Target Node20, with sample size of s500
# Retrieving results from test entropy-mi, Target Node202, with sample size of s500
# Retrieving results from test entropy-mi, Target Node205, with sample size of s500
# Retrieving results from test entropy-mi, Target Node209, with sample size of s500
# Retrieving results from test entropy-mi, Target Node212, with sample size of s500
# Retrieving results from test entropy-mi, Target Node213, with sample size of s500
# Retrieving results from test entropy-mi, Target Node215, with sample size of s500
# Retrieving results from test entropy-mi, Target Node216, with sample size of s500
# Retrieving results from test entropy-mi, Target Node221, with sample size of s500
# Retrieving results from test entropy-mi, Target Node222, with sample size of s500
# Retrieving results from test entropy-mi, Target Node228, with sample size of s500
# Retrieving results from test entropy-mi, Target Node231, with sample size of s500
# Retrieving results from test entropy-mi, Target Node233, with sample size of s500
# Retrieving results from test entropy-mi, Target Node236, with sample size of s500
# Retrieving results from test entropy-mi, Target Node239, with sample size of s500
# Retrieving results from test entropy-mi, Target Node24, with sample size of s500
# Retrieving results from test entropy-mi, Target Node242, with sample size of s500
# Retrieving results from test entropy-mi, Target Node246, with sample size of s500
# Retrieving results from test entropy-mi, Target Node249, with sample size of s500
# Retrieving results from test entropy-mi, Target Node250, with sample size of s500
# Retrieving results from test entropy-mi, Target Node252, with sample size of s500
# Retrieving results from test entropy-mi, Target Node253, with sample size of s500
# Retrieving results from test entropy-mi, Target Node258, with sample size of s500
# Retrieving results from test entropy-mi, Target Node259, with sample size of s500
# Retrieving results from test entropy-mi, Target Node265, with sample size of s500
# Retrieving results from test entropy-mi, Target Node268, with sample size of s500
# Retrieving results from test entropy-mi, Target Node27, with sample size of s500
# Retrieving results from test entropy-mi, Target Node270, with sample size of s500
# Retrieving results from test entropy-mi, Target Node273, with sample size of s500
# Retrieving results from test entropy-mi, Target Node276, with sample size of s500
# Retrieving results from test entropy-mi, Target Node279, with sample size of s500
# Retrieving results from test entropy-mi, Target Node28, with sample size of s500
# Retrieving results from test entropy-mi, Target Node283, with sample size of s500
# Retrieving results from test entropy-mi, Target Node286, with sample size of s500
# Retrieving results from test entropy-mi, Target Node287, with sample size of s500
# Retrieving results from test entropy-mi, Target Node289, with sample size of s500
# Retrieving results from test entropy-mi, Target Node290, with sample size of s500
# Retrieving results from test entropy-mi, Target Node295, with sample size of s500
# Retrieving results from test entropy-mi, Target Node296, with sample size of s500
# Retrieving results from test entropy-mi, Target Node30, with sample size of s500
# Retrieving results from test entropy-mi, Target Node302, with sample size of s500
# Retrieving results from test entropy-mi, Target Node305, with sample size of s500
# Retrieving results from test entropy-mi, Target Node307, with sample size of s500
# Retrieving results from test entropy-mi, Target Node31, with sample size of s500
# Retrieving results from test entropy-mi, Target Node310, with sample size of s500
# Retrieving results from test entropy-mi, Target Node313, with sample size of s500
# Retrieving results from test entropy-mi, Target Node316, with sample size of s500
# Retrieving results from test entropy-mi, Target Node320, with sample size of s500
# Retrieving results from test entropy-mi, Target Node323, with sample size of s500
# Retrieving results from test entropy-mi, Target Node324, with sample size of s500
# Retrieving results from test entropy-mi, Target Node326, with sample size of s500
# Retrieving results from test entropy-mi, Target Node327, with sample size of s500
# Retrieving results from test entropy-mi, Target Node332, with sample size of s500
# Retrieving results from test entropy-mi, Target Node333, with sample size of s500
# Retrieving results from test entropy-mi, Target Node339, with sample size of s500
# Retrieving results from test entropy-mi, Target Node342, with sample size of s500
# Retrieving results from test entropy-mi, Target Node344, with sample size of s500
# Retrieving results from test entropy-mi, Target Node347, with sample size of s500
# Retrieving results from test entropy-mi, Target Node350, with sample size of s500
# Retrieving results from test entropy-mi, Target Node353, with sample size of s500
# Retrieving results from test entropy-mi, Target Node357, with sample size of s500
# Retrieving results from test entropy-mi, Target Node36, with sample size of s500
# Retrieving results from test entropy-mi, Target Node360, with sample size of s500
# Retrieving results from test entropy-mi, Target Node361, with sample size of s500
# Retrieving results from test entropy-mi, Target Node363, with sample size of s500
# Retrieving results from test entropy-mi, Target Node364, with sample size of s500
# Retrieving results from test entropy-mi, Target Node369, with sample size of s500
# Retrieving results from test entropy-mi, Target Node37, with sample size of s500
# Retrieving results from test entropy-mi, Target Node370, with sample size of s500
# Retrieving results from test entropy-mi, Target Node43, with sample size of s500
# Retrieving results from test entropy-mi, Target Node46, with sample size of s500
# Retrieving results from test entropy-mi, Target Node48, with sample size of s500
# Retrieving results from test entropy-mi, Target Node51, with sample size of s500
# Retrieving results from test entropy-mi, Target Node54, with sample size of s500
# Retrieving results from test entropy-mi, Target Node57, with sample size of s500
# Retrieving results from test entropy-mi, Target Node6, with sample size of s500
# Retrieving results from test entropy-mi, Target Node61, with sample size of s500
# Retrieving results from test entropy-mi, Target Node64, with sample size of s500
# Retrieving results from test entropy-mi, Target Node65, with sample size of s500
# Retrieving results from test entropy-mi, Target Node67, with sample size of s500
# Retrieving results from test entropy-mi, Target Node68, with sample size of s500
# Retrieving results from test entropy-mi, Target Node73, with sample size of s500
# Retrieving results from test entropy-mi, Target Node74, with sample size of s500
# Retrieving results from test entropy-mi, Target Node80, with sample size of s500
# Retrieving results from test entropy-mi, Target Node83, with sample size of s500
# Retrieving results from test entropy-mi, Target Node85, with sample size of s500
# Retrieving results from test entropy-mi, Target Node88, with sample size of s500
# Retrieving results from test entropy-mi, Target Node9, with sample size of s500
# Retrieving results from test entropy-mi, Target Node91, with sample size of s500
# Retrieving results from test entropy-mi, Target Node94, with sample size of s500
# Retrieving results from test entropy-mi, Target Node98, with sample size of s500
# Retrieving results from test entropy-mi, Target Node101, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node102, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node104, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node105, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node11, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node110, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node111, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node117, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node120, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node122, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node125, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node128, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node131, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node135, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node138, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node139, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node14, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node141, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node142, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node147, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node148, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node154, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node157, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node159, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node162, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node165, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node168, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node17, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node172, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node175, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node176, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node178, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node179, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node184, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node185, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node191, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node194, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node196, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node199, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node20, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node202, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node205, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node209, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node212, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node213, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node215, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node216, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node221, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node222, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node228, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node231, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node233, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node236, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node239, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node24, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node242, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node246, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node249, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node250, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node252, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node253, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node258, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node259, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node265, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node268, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node27, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node270, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node273, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node276, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node279, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node28, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node283, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node286, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node287, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node289, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node290, with sample size of s1000
# Retrieving results from test entropy-mi, Target Node295, with sample size of s1000
# ...
# Retrieving results from test supercpc, Target Node259, with sample size of s1000
# Retrieving results from test supercpc, Target Node265, with sample size of s1000
# Retrieving results from test supercpc, Target Node268, with sample size of s1000
# Retrieving results from test supercpc, Target Node27, with sample size of s1000
# Retrieving results from test supercpc, Target Node270, with sample size of s1000
# Retrieving results from test supercpc, Target Node273, with sample size of s1000
# Retrieving results from test supercpc, Target Node276, with sample size of s1000
# Retrieving results from test supercpc, Target Node279, with sample size of s1000
# Retrieving results from test supercpc, Target Node28, with sample size of s1000
# Retrieving results from test supercpc, Target Node283, with sample size of s1000
# Retrieving results from test supercpc, Target Node286, with sample size of s1000
# Retrieving results from test supercpc, Target Node287, with sample size of s1000
# Retrieving results from test supercpc, Target Node289, with sample size of s1000
# Retrieving results from test supercpc, Target Node290, with sample size of s1000
# Retrieving results from test supercpc, Target Node295, with sample size of s1000
# Retrieving results from test supercpc, Target Node296, with sample size of s1000
# Retrieving results from test supercpc, Target Node30, with sample size of s1000
# Retrieving results from test supercpc, Target Node302, with sample size of s1000
# Retrieving results from test supercpc, Target Node305, with sample size of s1000
# Retrieving results from test supercpc, Target Node307, with sample size of s1000
# Retrieving results from test supercpc, Target Node31, with sample size of s1000
# Retrieving results from test supercpc, Target Node310, with sample size of s1000
# Retrieving results from test supercpc, Target Node313, with sample size of s1000
# Retrieving results from test supercpc, Target Node316, with sample size of s1000
# Retrieving results from test supercpc, Target Node320, with sample size of s1000
# Retrieving results from test supercpc, Target Node323, with sample size of s1000
# Retrieving results from test supercpc, Target Node324, with sample size of s1000
# Retrieving results from test supercpc, Target Node326, with sample size of s1000
# Retrieving results from test supercpc, Target Node327, with sample size of s1000
# Retrieving results from test supercpc, Target Node332, with sample size of s1000
# Retrieving results from test supercpc, Target Node333, with sample size of s1000
# Retrieving results from test supercpc, Target Node339, with sample size of s1000
# Retrieving results from test supercpc, Target Node342, with sample size of s1000
# Retrieving results from test supercpc, Target Node344, with sample size of s1000
# Retrieving results from test supercpc, Target Node347, with sample size of s1000
# Retrieving results from test supercpc, Target Node350, with sample size of s1000
# Retrieving results from test supercpc, Target Node353, with sample size of s1000
# Retrieving results from test supercpc, Target Node357, with sample size of s1000
# Retrieving results from test supercpc, Target Node36, with sample size of s1000
# Retrieving results from test supercpc, Target Node360, with sample size of s1000
# Retrieving results from test supercpc, Target Node361, with sample size of s1000
# Retrieving results from test supercpc, Target Node363, with sample size of s1000
# Retrieving results from test supercpc, Target Node364, with sample size of s1000
# Retrieving results from test supercpc, Target Node369, with sample size of s1000
# Retrieving results from test supercpc, Target Node37, with sample size of s1000
# Retrieving results from test supercpc, Target Node370, with sample size of s1000
# Retrieving results from test supercpc, Target Node43, with sample size of s1000
# Retrieving results from test supercpc, Target Node46, with sample size of s1000
# Retrieving results from test supercpc, Target Node48, with sample size of s1000
# Retrieving results from test supercpc, Target Node51, with sample size of s1000
# Retrieving results from test supercpc, Target Node54, with sample size of s1000
# Retrieving results from test supercpc, Target Node57, with sample size of s1000
# Retrieving results from test supercpc, Target Node6, with sample size of s1000
# Retrieving results from test supercpc, Target Node61, with sample size of s1000
# Retrieving results from test supercpc, Target Node64, with sample size of s1000
# Retrieving results from test supercpc, Target Node65, with sample size of s1000
# Retrieving results from test supercpc, Target Node67, with sample size of s1000
# Retrieving results from test supercpc, Target Node68, with sample size of s1000
# Retrieving results from test supercpc, Target Node73, with sample size of s1000
# Retrieving results from test supercpc, Target Node74, with sample size of s1000
# Retrieving results from test supercpc, Target Node80, with sample size of s1000
# Retrieving results from test supercpc, Target Node83, with sample size of s1000
# Retrieving results from test supercpc, Target Node85, with sample size of s1000
# Retrieving results from test supercpc, Target Node88, with sample size of s1000
# Retrieving results from test supercpc, Target Node9, with sample size of s1000
# Retrieving results from test supercpc, Target Node91, with sample size of s1000
# Retrieving results from test supercpc, Target Node94, with sample size of s1000
# Retrieving results from test supercpc, Target Node98, with sample size of s1000
# Retrieving results from test supercpc, Target Node101, with sample size of s5000
# Retrieving results from test supercpc, Target Node102, with sample size of s5000
# Retrieving results from test supercpc, Target Node104, with sample size of s5000
# Retrieving results from test supercpc, Target Node105, with sample size of s5000
# Retrieving results from test supercpc, Target Node11, with sample size of s5000
# Retrieving results from test supercpc, Target Node110, with sample size of s5000
# Retrieving results from test supercpc, Target Node111, with sample size of s5000
# Retrieving results from test supercpc, Target Node117, with sample size of s5000
# Retrieving results from test supercpc, Target Node120, with sample size of s5000
# Retrieving results from test supercpc, Target Node122, with sample size of s5000
# Retrieving results from test supercpc, Target Node125, with sample size of s5000
# Retrieving results from test supercpc, Target Node128, with sample size of s5000
# Retrieving results from test supercpc, Target Node131, with sample size of s5000
# Retrieving results from test supercpc, Target Node135, with sample size of s5000
# Retrieving results from test supercpc, Target Node138, with sample size of s5000
# Retrieving results from test supercpc, Target Node139, with sample size of s5000
# Retrieving results from test supercpc, Target Node14, with sample size of s5000
# Retrieving results from test supercpc, Target Node141, with sample size of s5000
# Retrieving results from test supercpc, Target Node142, with sample size of s5000
# Retrieving results from test supercpc, Target Node147, with sample size of s5000
# Retrieving results from test supercpc, Target Node148, with sample size of s5000
# Retrieving results from test supercpc, Target Node154, with sample size of s5000
# Retrieving results from test supercpc, Target Node157, with sample size of s5000
# Retrieving results from test supercpc, Target Node159, with sample size of s5000
# Retrieving results from test supercpc, Target Node162, with sample size of s5000
# Retrieving results from test supercpc, Target Node165, with sample size of s5000
# Retrieving results from test supercpc, Target Node168, with sample size of s5000
# Retrieving results from test supercpc, Target Node17, with sample size of s5000
# Retrieving results from test supercpc, Target Node172, with sample size of s5000
# Retrieving results from test supercpc, Target Node175, with sample size of s5000
# Retrieving results from test supercpc, Target Node176, with sample size of s5000
# Retrieving results from test supercpc, Target Node178, with sample size of s5000
# Retrieving results from test supercpc, Target Node179, with sample size of s5000
# Retrieving results from test supercpc, Target Node184, with sample size of s5000
# Retrieving results from test supercpc, Target Node185, with sample size of s5000
# Retrieving results from test supercpc, Target Node191, with sample size of s5000
# Retrieving results from test supercpc, Target Node194, with sample size of s5000
# Retrieving results from test supercpc, Target Node196, with sample size of s5000
# Retrieving results from test supercpc, Target Node199, with sample size of s5000
# Retrieving results from test supercpc, Target Node20, with sample size of s5000
# Retrieving results from test supercpc, Target Node202, with sample size of s5000
# Retrieving results from test supercpc, Target Node205, with sample size of s5000
# Retrieving results from test supercpc, Target Node209, with sample size of s5000
# Retrieving results from test supercpc, Target Node212, with sample size of s5000
# Retrieving results from test supercpc, Target Node213, with sample size of s5000
# Retrieving results from test supercpc, Target Node215, with sample size of s5000
# Retrieving results from test supercpc, Target Node216, with sample size of s5000
# Retrieving results from test supercpc, Target Node221, with sample size of s5000
# Retrieving results from test supercpc, Target Node222, with sample size of s5000
# Retrieving results from test supercpc, Target Node228, with sample size of s5000
# Retrieving results from test supercpc, Target Node231, with sample size of s5000
# Retrieving results from test supercpc, Target Node233, with sample size of s5000
# Retrieving results from test supercpc, Target Node236, with sample size of s5000
# Retrieving results from test supercpc, Target Node239, with sample size of s5000
# Retrieving results from test supercpc, Target Node24, with sample size of s5000
# Retrieving results from test supercpc, Target Node242, with sample size of s5000
# Retrieving results from test supercpc, Target Node246, with sample size of s5000
# Retrieving results from test supercpc, Target Node249, with sample size of s5000
# Retrieving results from test supercpc, Target Node250, with sample size of s5000
# Retrieving results from test supercpc, Target Node252, with sample size of s5000
# Retrieving results from test supercpc, Target Node253, with sample size of s5000
# Retrieving results from test supercpc, Target Node258, with sample size of s5000
# Retrieving results from test supercpc, Target Node259, with sample size of s5000
# Retrieving results from test supercpc, Target Node265, with sample size of s5000
# Retrieving results from test supercpc, Target Node268, with sample size of s5000
# Retrieving results from test supercpc, Target Node27, with sample size of s5000
# Retrieving results from test supercpc, Target Node270, with sample size of s5000
# Retrieving results from test supercpc, Target Node273, with sample size of s5000
# Retrieving results from test supercpc, Target Node276, with sample size of s5000
# Retrieving results from test supercpc, Target Node279, with sample size of s5000
# Retrieving results from test supercpc, Target Node28, with sample size of s5000
# Retrieving results from test supercpc, Target Node283, with sample size of s5000
# Retrieving results from test supercpc, Target Node286, with sample size of s5000
# Retrieving results from test supercpc, Target Node287, with sample size of s5000
# Retrieving results from test supercpc, Target Node289, with sample size of s5000
# Retrieving results from test supercpc, Target Node290, with sample size of s5000
# Retrieving results from test supercpc, Target Node295, with sample size of s5000
# Retrieving results from test supercpc, Target Node296, with sample size of s5000
# Retrieving results from test supercpc, Target Node30, with sample size of s5000
# Retrieving results from test supercpc, Target Node302, with sample size of s5000
# Retrieving results from test supercpc, Target Node305, with sample size of s5000
# Retrieving results from test supercpc, Target Node307, with sample size of s5000
# Retrieving results from test supercpc, Target Node31, with sample size of s5000
# Retrieving results from test supercpc, Target Node310, with sample size of s5000
# Retrieving results from test supercpc, Target Node313, with sample size of s5000
# Retrieving results from test supercpc, Target Node316, with sample size of s5000
# Retrieving results from test supercpc, Target Node320, with sample size of s5000
# Retrieving results from test supercpc, Target Node323, with sample size of s5000
# Retrieving results from test supercpc, Target Node324, with sample size of s5000
# Retrieving results from test supercpc, Target Node326, with sample size of s5000
# Retrieving results from test supercpc, Target Node327, with sample size of s5000
# Retrieving results from test supercpc, Target Node332, with sample size of s5000
# Retrieving results from test supercpc, Target Node333, with sample size of s5000
# Retrieving results from test supercpc, Target Node339, with sample size of s5000
# Retrieving results from test supercpc, Target Node342, with sample size of s5000
# Retrieving results from test supercpc, Target Node344, with sample size of s5000
# Retrieving results from test supercpc, Target Node347, with sample size of s5000
# Retrieving results from test supercpc, Target Node350, with sample size of s5000
# Retrieving results from test supercpc, Target Node353, with sample size of s5000
# Retrieving results from test supercpc, Target Node357, with sample size of s5000
# Retrieving results from test supercpc, Target Node36, with sample size of s5000
# Retrieving results from test supercpc, Target Node360, with sample size of s5000
# Retrieving results from test supercpc, Target Node361, with sample size of s5000
# Retrieving results from test supercpc, Target Node363, with sample size of s5000
# Retrieving results from test supercpc, Target Node364, with sample size of s5000
# Retrieving results from test supercpc, Target Node369, with sample size of s5000
# Retrieving results from test supercpc, Target Node37, with sample size of s5000
# Retrieving results from test supercpc, Target Node370, with sample size of s5000
# Retrieving results from test supercpc, Target Node43, with sample size of s5000
# Retrieving results from test supercpc, Target Node46, with sample size of s5000
# Retrieving results from test supercpc, Target Node48, with sample size of s5000
# Retrieving results from test supercpc, Target Node51, with sample size of s5000
# Retrieving results from test supercpc, Target Node54, with sample size of s5000
# Retrieving results from test supercpc, Target Node57, with sample size of s5000
# Retrieving results from test supercpc, Target Node6, with sample size of s5000
# Retrieving results from test supercpc, Target Node61, with sample size of s5000
# Retrieving results from test supercpc, Target Node64, with sample size of s5000
# Retrieving results from test supercpc, Target Node65, with sample size of s5000
# Retrieving results from test supercpc, Target Node67, with sample size of s5000
# Retrieving results from test supercpc, Target Node68, with sample size of s5000
# Retrieving results from test supercpc, Target Node73, with sample size of s5000
# Retrieving results from test supercpc, Target Node74, with sample size of s5000
# Retrieving results from test supercpc, Target Node80, with sample size of s5000
# Retrieving results from test supercpc, Target Node83, with sample size of s5000
# Retrieving results from test supercpc, Target Node85, with sample size of s5000
# Retrieving results from test supercpc, Target Node88, with sample size of s5000
# Retrieving results from test supercpc, Target Node9, with sample size of s5000
# Retrieving results from test supercpc, Target Node91, with sample size of s5000
# Retrieving results from test supercpc, Target Node94, with sample size of s5000
# Retrieving results from test supercpc, Target Node98, with sample size of s5000

# %%
balance_ranking[0]
# Out:
# ['true-mb', 's500', 'Node101', 0.024550565830399974, 0.39802172228811467]

# %%
# processing and making graphic of results

# %matplotlib inline
"""
Plotting a three-way ANOVA
==========================

_thumb: .42, .5
"""
import seaborn as sns
sns.set(style="whitegrid")

# Creating the df
df = pd.DataFrame(columns=["Balance Rank", "G-mean","Feature Selection Method","Number of samples"])

# sumarizing data for intervals of 0.25

ticks_step = 0.10
step_top = 0.60

steps_arr = np.arange(0.0,step_top,ticks_step)

size_label = []

for i in range(0,len(steps_arr)):
    #print(steps_arr[i])
    size_label.append(len([x for x in balance_ranking 
                           if x[0]==recovery_files[0].split('_')[1] 
                           and x[1]==sample_sizes[2]
                           and (x[3]>=steps_arr[i]  and x[3] < steps_arr[i]+ticks_step)]))

#print(size_label)
for e in balance_ranking:
    # calculating which range it is in
    b_rank_counter=0
    for b_counter in range(0,len(steps_arr)):
        if ((steps_arr[b_counter]+ticks_step)>e[3]):
            break
        b_rank_counter=b_rank_counter+1
    
    
    df = df.append({
             "Balance Rank":str(math.ceil(100*steps_arr[b_rank_counter])/100) +
                                ' - ' + 
                            str(math.ceil(100*(steps_arr[b_rank_counter]+ticks_step))/100)+
                            '\n '+str(size_label[b_rank_counter]), 
            "G-mean":e[4],
            "Feature Selection Method":e[0],
            "Number of samples":int(e[1].split('s')[1])
              }, ignore_index=True)
# Draw a pointplot to show pulse as a function of three categorical factors
sns.set_color_codes("pastel")
g = sns.factorplot(x="Balance Rank", y="G-mean", hue="Feature Selection Method",
                   col="Number of samples", data=df,
                   capsize=.2, palette="YlGnBu_d", size=7, aspect=1.5)

g.despine(left=True)

g.set(yticks=np.arange(0.0,1.0,0.05))

# %%
# Out:
# [110, 19, 1]

# %%
#

# %%
def balance_scoring(size1, size2):
    f_size1 = float(size1)
    f_size2 = float(size2)
    if (f_size1/f_size2 <= 1):
        return f_size1/f_size2
    else:
        return f_size2/f_size1

# %%
def g_mean(precision_arr):
    counter=1
    for e in precision_arr:
        counter=counter*e[2]
    
    return counter**(1/len(precision_arr))

# %%
import pandas as pd
import numpy as np
from sklearn.naive_bayes import GaussianNB
from ipynb.fs.defs.MMRWPC import MMRWPC
from ipynb.fs.defs.MMPC import MMPC
from ipynb.fs.defs.MMPC_opt import MMPC_opt
import time
import os
from ipynb.fs.defs.GraphReader import GraphReader

# %%
class MMPC_sequential_testing():
    
    def __init__(self, mmpc_models, model_names, testing_dataset_route, log_route, selected_nodes_route,
                 graph_info_route, n_shuffles):
        
        self._mmpc_models = mmpc_models
        self._model_names = model_names
        self._testing_dataset_route = testing_dataset_route
        self._log_route = log_route
        self._n_shuffles = n_shuffles
        self._graph_reader = GraphReader(graph_info_route)
        self._files_dict = None
        self._results = None
        preselected_nodes = []
        try:
            ff = open(selected_nodes_route,'r')
            for e in ff.read().split('\n'):
                spl_line = e.split(';')
                if (len(spl_line[0])==0):
                    continue
                preselected_nodes.append(spl_line[0])
            ff.close()
        except:
            print("Error opening preselected nodes file")
            return
        
        self._selected_nodes = preselected_nodes
        self.__init_files()
        print("MMPC_Testing object succesfully created.")
        
        return
    
    def __init_files(self):
        
        files_dict = {}
        for filename in os.listdir(self._testing_dataset_route):
            temp_df = pd.read_csv(
                self._testing_dataset_route+
                filename,delimiter='  ',header=None, engine='python')
            graph_heads = []
            for k in range(0,len(temp_df.columns)):
                graph_heads.append('Node'+str(k+1))
            temp_df.columns = graph_heads
            files_dict[filename] = temp_df
            print(filename)
        
        self._files_dict = files_dict
        return
    
    def getResults(self):
        if self._results is None:
            print("No calculated results yet.")
            
            return []
        
        return list(self._results)
    
    def __write_out_pobdict(self, pobdict):
        ff = open(self._log_route+'sequential_results_'+pobdict['dataset'].replace('.txt','').replace('_','')+'_'+pobdict['TargetNode']+'.txt', 'w')
        model_results = pobdict['models_results']
        for e in model_results:
            ff.write(e['model_name']+';')
            ff.write(str(e['model_time'])+';')
            ff.write(str(e['pc_distance'])+';')
            for node in e['model_CPC']:
                ff.write(node['name']+',')
            ff.write('\n')
        ff.close()
        
        return
    
    def __evaluate(self, PCs):
        
        processed_pc_list = []
        for file_dict in self._files_dict:
            nodes_to_process = [x for x in PCs if x['dataset'] == file_dict]
            pcs_index = [int(x['TargetNode'].split('@')[0].split('Node')[1])-1 for x in nodes_to_process]
            for model_c in range(0,len(self._mmpc_models)):
                self._mmpc_models[model_c].fit(self._files_dict[file_dict])
            
            
            for nodes_c in range(0, len(nodes_to_process)):
                pob_dict = {}
                pob_dict['dataset'] = file_dict
                pob_dict['TargetNode'] = nodes_to_process[nodes_c]['TargetNode']
                pob_dict['models_results'] = []
                for model_c in range(0,len(self._mmpc_models)):
                    for shuffle_c in range(0,self._n_shuffles):
                        self._mmpc_models[model_c].shuffle_rows()
                        model_results = self._mmpc_models[model_c].evaluate(pcs_index[nodes_c])
                        results_dict = {}
                        results_dict['model_name'] = self._model_names[model_c]
                        results_dict['model_time'] = model_results['time']
                        results_dict['model_CPC'] = model_results['CPC']
                        results_dict['pc_distance'] = self._graph_reader.getDistance(pcs_index[nodes_c],[x['name'].split('@')[0] for x in results_dict['model_CPC']])
                        pob_dict['models_results'].append(results_dict)
                
                # write out results in formatted file
                self.__write_out_pobdict(pob_dict)
                
                # save info
                processed_pc_list.append(pob_dict)        
            
                
        return processed_pc_list
    
    def __getNodeDicts(self):
        """
        Create list of parameters to pass
        for a parallel execution including
        the file to examine and the node to examine
        """
        pob_dicts = []
        for node in self._selected_nodes:
            for filename in os.listdir(self._testing_dataset_route):
                pob_dict = {}
                pob_dict['dataset'] = filename
                pob_dict['TargetNode'] = node
                pob_dicts.append(pob_dict)
        
        return pob_dicts
    
    def test_models(self):
        PCs = self.__getNodeDicts()
        model_pcs = self.__evaluate(PCs)
#         scored_pcs = Parallel(n_jobs=10)(map(delayed(self.__scorePC),PCs))
#         self._results = scored_pcs
        self._results = model_pcs
        
        return

# %%
seq_testing  = MMPC_sequential_testing(
                            [MMRWPC(0.05,0.0,1), MMPC_opt(0.05),MMPC(0.05)],
                            ['MMRWPC','MMPCOPT','MMPC'],
                            '/home/a20114261/sdelrio/alarm_datasets/Alarm10/', 
                            '/home/a20114261/sdelrio/alarm_datasets/log_sequential_results/',
                            '/home/a20114261/sdelrio/alarm_datasets/log_results/mmpc_partitioned/alarm10_binary_nodes_selected.txt',
                            '/home/a20114261/sdelrio/Alarm10_graph.txt',
                            5)
# Out:
# Random Walk successful instantiation with:
# -Alpha: 0.05
# -Delta: 0.0
# -Max Neighbours per run: 1
# Alarm10_s1000_v4.txt
# Alarm10_s500_v7.txt
# Alarm10_s5000_v1.txt
# Alarm10_s5000_v9.txt
# Alarm10_s500_v6.txt
# Alarm10_s1000_v8.txt
# Alarm10_s5000_v8.txt
# Alarm10_s1000_v1.txt
# Alarm10_s1000_v5.txt
# Alarm10_s500_v9.txt
# Alarm10_s1000_v6.txt
# Alarm10_s500_v2.txt
# Alarm10_s5000_v5.txt
# Alarm10_s500_v1.txt
# Alarm10_s5000_v4.txt
# Alarm10_s1000_v7.txt
# Alarm10_s500_v4.txt
# Alarm10_s5000_v2.txt
# Alarm10_s1000_v3.txt
# Alarm10_s1000_v2.txt
# Alarm10_s5000_v6.txt
# Alarm10_s500_v3.txt
# Alarm10_s1000_v10.txt
# Alarm10_s5000_v7.txt
# Alarm10_s500_v5.txt
# Alarm10_s500_v10.txt
# Alarm10_s5000_v3.txt
# Alarm10_s500_v8.txt
# Alarm10_s5000_v10.txt
# Alarm10_s1000_v9.txt
# MMPC_Testing object succesfully created.

# %%
seq_testing.test_models()
# Out:
# Succesful instantiation of Dep object
# Succesfully fitted array of 370 columns
# and 1000 rows per column.
# Succesful instantiation of Dep object
# Finished fitting of X in MMPC object
# Finished fitting of X in MMPC object
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node76@4']
#
# Universe actual size:
# 4
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node76@4', 'Node96@4']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node96@4', 'Node76@4']
#
# Universe actual size:
# 3
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node76@4', 'Node96@4', 'Node39@4']
# n_set of length: 3
# CPC size after filtering: 3
# ['Node39@4', 'Node96@4', 'Node76@4']
#
# Universe actual size:
# 1
# CPC size before filtering: 4
# Size set for community selection phase will be of maximum: 3
# ['Node76@4', 'Node96@4', 'Node39@4', 'Node78@4']
# n_set of length: 4
# CPC size after filtering: 4
# ['Node78@4', 'Node39@4', 'Node96@4', 'Node76@4']
#
# Universe actual size:
# 0
# CPC size before filtering: 5
# Size set for community selection phase will be of maximum: 4
# ['Node76@4', 'Node23@4', 'Node96@4', 'Node39@4', 'Node78@4']
# n_set of length: 5
# CPC size after filtering: 4
# ['Node39@4', 'Node96@4', 'Node23@4', 'Node76@4']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node76@4']
#
# Universe actual size:
# 4
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node76@4', 'Node96@4']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node96@4', 'Node76@4']
#
# Universe actual size:
# 3
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node76@4', 'Node96@4', 'Node39@4']
# n_set of length: 3
# CPC size after filtering: 3
# ['Node39@4', 'Node96@4', 'Node76@4']
#
# Universe actual size:
# 1
# CPC size before filtering: 4
# Size set for community selection phase will be of maximum: 3
# ['Node76@4', 'Node96@4', 'Node39@4', 'Node78@4']
# n_set of length: 4
# CPC size after filtering: 4
# ['Node78@4', 'Node39@4', 'Node96@4', 'Node76@4']
#
# Universe actual size:
# 0
# CPC size before filtering: 5
# Size set for community selection phase will be of maximum: 4
# ['Node76@4', 'Node23@4', 'Node96@4', 'Node39@4', 'Node78@4']
# n_set of length: 5
# CPC size after filtering: 4
# ['Node39@4', 'Node96@4', 'Node23@4', 'Node76@4']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node76@4']
#
# Universe actual size:
# 4
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node76@4', 'Node96@4']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node96@4', 'Node76@4']
#
# Universe actual size:
# 3
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node76@4', 'Node96@4', 'Node39@4']
# n_set of length: 3
# CPC size after filtering: 3
# ['Node39@4', 'Node96@4', 'Node76@4']
#
# Universe actual size:
# 1
# CPC size before filtering: 4
# Size set for community selection phase will be of maximum: 3
# ['Node76@4', 'Node96@4', 'Node39@4', 'Node78@4']
# n_set of length: 4
# CPC size after filtering: 4
# ['Node78@4', 'Node39@4', 'Node96@4', 'Node76@4']
#
# Universe actual size:
# 0
# CPC size before filtering: 5
# Size set for community selection phase will be of maximum: 4
# ['Node76@4', 'Node23@4', 'Node96@4', 'Node39@4', 'Node78@4']
# n_set of length: 5
# CPC size after filtering: 4
# ['Node39@4', 'Node96@4', 'Node23@4', 'Node76@4']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node76@4']
#
# Universe actual size:
# 4
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node76@4', 'Node96@4']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node96@4', 'Node76@4']
#
# Universe actual size:
# 3
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node76@4', 'Node96@4', 'Node39@4']
# n_set of length: 3
# CPC size after filtering: 3
# ['Node39@4', 'Node96@4', 'Node76@4']
#
# Universe actual size:
# 1
# CPC size before filtering: 4
# Size set for community selection phase will be of maximum: 3
# ['Node76@4', 'Node96@4', 'Node39@4', 'Node78@4']
# n_set of length: 4
# CPC size after filtering: 4
# ['Node78@4', 'Node39@4', 'Node96@4', 'Node76@4']
#
# Universe actual size:
# 0
# CPC size before filtering: 5
# Size set for community selection phase will be of maximum: 4
# ['Node76@4', 'Node23@4', 'Node96@4', 'Node39@4', 'Node78@4']
# n_set of length: 5
# CPC size after filtering: 4
# ['Node39@4', 'Node96@4', 'Node23@4', 'Node76@4']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node76@4']
#
# Universe actual size:
# 4
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node76@4', 'Node96@4']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node96@4', 'Node76@4']
#
# Universe actual size:
# 3
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node76@4', 'Node96@4', 'Node39@4']
# n_set of length: 3
# CPC size after filtering: 3
# ['Node39@4', 'Node96@4', 'Node76@4']
#
# Universe actual size:
# 1
# CPC size before filtering: 4
# Size set for community selection phase will be of maximum: 3
# ['Node76@4', 'Node96@4', 'Node39@4', 'Node78@4']
# n_set of length: 4
# CPC size after filtering: 4
# ['Node78@4', 'Node39@4', 'Node96@4', 'Node76@4']
#
# Universe actual size:
# 0
# CPC size before filtering: 5
# Size set for community selection phase will be of maximum: 4
# ['Node76@4', 'Node23@4', 'Node96@4', 'Node39@4', 'Node78@4']
# n_set of length: 5
# CPC size after filtering: 4
# ['Node39@4', 'Node96@4', 'Node23@4', 'Node76@4']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC actual size:
# 1
# CPC contents:
# ['Node76@4']
#
# Universe actual size:
# 4
# CPC actual size:
# 2
# CPC contents:
# ['Node76@4', 'Node96@4']
#
# Universe actual size:
# 3
# CPC actual size:
# 3
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4']
#
# Universe actual size:
# 1
# CPC actual size:
# 4
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4', 'Node39@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 5
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4', 'Node39@4', 'Node133@4']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC actual size:
# 1
# CPC contents:
# ['Node76@4']
#
# Universe actual size:
# 4
# CPC actual size:
# 2
# CPC contents:
# ['Node76@4', 'Node96@4']
#
# Universe actual size:
# 3
# CPC actual size:
# 3
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4']
#
# Universe actual size:
# 1
# CPC actual size:
# 4
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4', 'Node39@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 5
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4', 'Node39@4', 'Node133@4']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC actual size:
# 1
# CPC contents:
# ['Node76@4']
#
# Universe actual size:
# 4
# CPC actual size:
# 2
# CPC contents:
# ['Node76@4', 'Node96@4']
#
# Universe actual size:
# 3
# CPC actual size:
# 3
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4']
#
# Universe actual size:
# 1
# CPC actual size:
# 4
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4', 'Node39@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 5
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4', 'Node39@4', 'Node133@4']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC actual size:
# 1
# CPC contents:
# ['Node76@4']
#
# Universe actual size:
# 4
# CPC actual size:
# 2
# CPC contents:
# ['Node76@4', 'Node96@4']
#
# Universe actual size:
# 3
# CPC actual size:
# 3
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4']
#
# Universe actual size:
# 1
# CPC actual size:
# 4
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4', 'Node39@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 5
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4', 'Node39@4', 'Node133@4']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC actual size:
# 1
# CPC contents:
# ['Node76@4']
#
# Universe actual size:
# 4
# CPC actual size:
# 2
# CPC contents:
# ['Node76@4', 'Node96@4']
#
# Universe actual size:
# 3
# CPC actual size:
# 3
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4']
# Universe actual size:
# 1
# CPC actual size:
# 4
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4', 'Node39@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 5
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4', 'Node39@4', 'Node133@4']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC actual size:
# 1
# CPC contents:
# ['Node76@4']
#
# Universe actual size:
# 4
# CPC actual size:
# 2
# CPC contents:
# ['Node76@4', 'Node96@4']
#
# Universe actual size:
# 3
# CPC actual size:
# 3
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4']
#
# Universe actual size:
# 1
# CPC actual size:
# 4
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4', 'Node39@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 5
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4', 'Node39@4', 'Node133@4']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC actual size:
# 1
# CPC contents:
# ['Node76@4']
#
# Universe actual size:
# 4
# CPC actual size:
# 2
# CPC contents:
# ['Node76@4', 'Node96@4']
#
# Universe actual size:
# 3
# CPC actual size:
# 3
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4']
#
# Universe actual size:
# 1
# CPC actual size:
# 4
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4', 'Node39@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 5
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4', 'Node39@4', 'Node133@4']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC actual size:
# 1
# CPC contents:
# ['Node76@4']
#
# Universe actual size:
# 4
# CPC actual size:
# 2
# CPC contents:
# ['Node76@4', 'Node96@4']
#
# Universe actual size:
# 3
# CPC actual size:
# 3
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4']
#
# Universe actual size:
# 1
# CPC actual size:
# 4
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4', 'Node39@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 5
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4', 'Node39@4', 'Node133@4']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC actual size:
# 1
# CPC contents:
# ['Node76@4']
#
# Universe actual size:
# 4
# CPC actual size:
# 2
# CPC contents:
# ['Node76@4', 'Node96@4']
#
# Universe actual size:
# 3
# CPC actual size:
# 3
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4']
#
# Universe actual size:
# 1
# CPC actual size:
# 4
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4', 'Node39@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 5
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4', 'Node39@4', 'Node133@4']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC actual size:
# 1
# CPC contents:
# ['Node76@4']
#
# Universe actual size:
# 4
# CPC actual size:
# 2
# CPC contents:
# ['Node76@4', 'Node96@4']
#
# Universe actual size:
# 3
# CPC actual size:
# 3
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4']
#
# Universe actual size:
# 1
# CPC actual size:
# 4
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4', 'Node39@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 5
# CPC contents:
# ['Node76@4', 'Node96@4', 'Node23@4', 'Node39@4', 'Node133@4']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 11
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node103@3', 'Node92@3']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node92@3', 'Node103@3']
#
# Universe actual size:
# 6
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node92@3', 'Node103@3', 'Node88@2']
# n_set of length: 3
# CPC size after filtering: 2
# ['Node103@3', 'Node92@3']
#
# Universe actual size:
# 1
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node103@3', 'Node92@3', 'Node96@4']
# n_set of length: 3
# CPC size after filtering: 3
# ['Node96@4', 'Node92@3', 'Node103@3']
#
# Universe actual size:
# 0
# CPC size before filtering: 4
# Size set for community selection phase will be of maximum: 3
# ['Node92@3', 'Node103@3', 'Node96@4', 'Node89@3']
# n_set of length: 4
# CPC size after filtering: 4
# ['Node89@3', 'Node96@4', 'Node103@3', 'Node92@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 11
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node92@3', 'Node103@3']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node103@3', 'Node92@3']
#
# Universe actual size:
# 5
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node103@3', 'Node92@3', 'Node75@4']
# n_set of length: 3
# CPC size after filtering: 2
# ['Node92@3', 'Node103@3']
#
# Universe actual size:
# 1
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node92@3', 'Node103@3', 'Node89@3']
# n_set of length: 3
# CPC size after filtering: 3
# ['Node89@3', 'Node103@3', 'Node92@3']
#
# Universe actual size:
# 0
# CPC size before filtering: 4
# Size set for community selection phase will be of maximum: 3
# ['Node103@3', 'Node92@3', 'Node96@4', 'Node89@3']
# n_set of length: 4
# CPC size after filtering: 4
# ['Node89@3', 'Node96@4', 'Node92@3', 'Node103@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 11
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node92@3', 'Node103@3']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node103@3', 'Node92@3']
#
# Universe actual size:
# 5
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node103@3', 'Node92@3', 'Node75@4']
# n_set of length: 3
# CPC size after filtering: 2
# ['Node92@3', 'Node103@3']
#
# Universe actual size:
# 1
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node92@3', 'Node103@3', 'Node89@3']
# n_set of length: 3
# CPC size after filtering: 3
# ['Node89@3', 'Node103@3', 'Node92@3']
#
# Universe actual size:
# 0
# CPC size before filtering: 4
# Size set for community selection phase will be of maximum: 3
# ['Node103@3', 'Node92@3', 'Node96@4', 'Node89@3']
# n_set of length: 4
# CPC size after filtering: 4
# ['Node89@3', 'Node96@4', 'Node92@3', 'Node103@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 11
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node92@3', 'Node103@3']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node103@3', 'Node92@3']
#
# Universe actual size:
# 5
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node103@3', 'Node92@3', 'Node75@4']
# n_set of length: 3
# CPC size after filtering: 2
# ['Node92@3', 'Node103@3']
#
# Universe actual size:
# 1
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node92@3', 'Node103@3', 'Node89@3']
# n_set of length: 3
# CPC size after filtering: 3
# ['Node89@3', 'Node103@3', 'Node92@3']
#
# Universe actual size:
# 0
# CPC size before filtering: 4
# Size set for community selection phase will be of maximum: 3
# ['Node103@3', 'Node92@3', 'Node96@4', 'Node89@3']
# n_set of length: 4
# CPC size after filtering: 4
# ['Node89@3', 'Node96@4', 'Node92@3', 'Node103@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 11
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node92@3', 'Node103@3']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node103@3', 'Node92@3']
#
# Universe actual size:
# 5
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node103@3', 'Node92@3', 'Node75@4']
# n_set of length: 3
# CPC size after filtering: 2
# ['Node92@3', 'Node103@3']
#
# Universe actual size:
# 1
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node92@3', 'Node103@3', 'Node89@3']
# n_set of length: 3
# CPC size after filtering: 3
# ['Node89@3', 'Node103@3', 'Node92@3']
#
# Universe actual size:
# 0
# CPC size before filtering: 4
# Size set for community selection phase will be of maximum: 3
# ['Node103@3', 'Node92@3', 'Node96@4', 'Node89@3']
# n_set of length: 4
# CPC size after filtering: 4
# ['Node89@3', 'Node96@4', 'Node92@3', 'Node103@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 12
# CPC actual size:
# 1
# CPC contents:
# ['Node103@3']
#
# Universe actual size:
# 7
# CPC actual size:
# 2
# CPC contents:
# ['Node103@3', 'Node92@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 3
# CPC contents:
# ['Node103@3', 'Node92@3', 'Node96@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 4
# CPC contents:
# ['Node103@3', 'Node92@3', 'Node96@4', 'Node89@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
# Universe actual size:
# 12
# CPC actual size:
# 1
# CPC contents:
# ['Node92@3']
#
# Universe actual size:
# 6
# CPC actual size:
# 2
# CPC contents:
# ['Node92@3', 'Node103@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 3
# CPC contents:
# ['Node92@3', 'Node103@3', 'Node89@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 4
# CPC contents:
# ['Node92@3', 'Node103@3', 'Node89@3', 'Node96@4']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 12
# CPC actual size:
# 1
# CPC contents:
# ['Node103@3']
#
# Universe actual size:
# 7
# CPC actual size:
# 2
# CPC contents:
# ['Node103@3', 'Node92@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 3
# CPC contents:
# ['Node103@3', 'Node92@3', 'Node96@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 4
# CPC contents:
# ['Node103@3', 'Node92@3', 'Node96@4', 'Node89@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 12
# CPC actual size:
# 1
# CPC contents:
# ['Node103@3']
#
# Universe actual size:
# 7
# CPC actual size:
# 2
# CPC contents:
# ['Node103@3', 'Node92@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 3
# CPC contents:
# ['Node103@3', 'Node92@3', 'Node96@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 4
# CPC contents:
# ['Node103@3', 'Node92@3', 'Node96@4', 'Node89@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 12
# CPC actual size:
# 1
# CPC contents:
# ['Node92@3']
#
# Universe actual size:
# 6
# CPC actual size:
# 2
# CPC contents:
# ['Node92@3', 'Node103@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 3
# CPC contents:
# ['Node92@3', 'Node103@3', 'Node89@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 4
# CPC contents:
# ['Node92@3', 'Node103@3', 'Node89@3', 'Node96@4']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 12
# CPC actual size:
# 1
# CPC contents:
# ['Node103@3']
#
# Universe actual size:
# 7
# CPC actual size:
# 2
# CPC contents:
# ['Node103@3', 'Node92@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 3
# CPC contents:
# ['Node103@3', 'Node92@3', 'Node96@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 4
# CPC contents:
# ['Node103@3', 'Node92@3', 'Node96@4', 'Node89@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 12
# CPC actual size:
# 1
# CPC contents:
# ['Node103@3']
#
# Universe actual size:
# 7
# CPC actual size:
# 2
# CPC contents:
# ['Node103@3', 'Node92@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 3
# CPC contents:
# ['Node103@3', 'Node92@3', 'Node96@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 4
# CPC contents:
# ['Node103@3', 'Node92@3', 'Node96@4', 'Node89@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 12
# CPC actual size:
# 1
# CPC contents:
# ['Node92@3']
#
# Universe actual size:
# 6
# CPC actual size:
# 2
# CPC contents:
# ['Node92@3', 'Node103@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 3
# CPC contents:
# ['Node92@3', 'Node103@3', 'Node89@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 4
# CPC contents:
# ['Node92@3', 'Node103@3', 'Node89@3', 'Node96@4']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 12
# CPC actual size:
# 1
# CPC contents:
# ['Node103@3']
#
# Universe actual size:
# 7
# CPC actual size:
# 2
# CPC contents:
# ['Node103@3', 'Node92@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 3
# CPC contents:
# ['Node103@3', 'Node92@3', 'Node96@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 4
# CPC contents:
# ['Node103@3', 'Node92@3', 'Node96@4', 'Node89@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 12
# CPC actual size:
# 1
# CPC contents:
# ['Node103@3']
#
# Universe actual size:
# 7
# CPC actual size:
# 2
# CPC contents:
# ['Node103@3', 'Node92@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 3
# CPC contents:
# ['Node103@3', 'Node92@3', 'Node96@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 4
# CPC contents:
# ['Node103@3', 'Node92@3', 'Node96@4', 'Node89@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node77@3']
#
# Universe actual size:
# 2
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node77@3', 'Node38@4']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node38@4', 'Node77@3']
#
# Universe actual size:
# 1
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node77@3', 'Node66@3', 'Node38@4']
# n_set of length: 3
# CPC size after filtering: 2
# ['Node66@3', 'Node77@3']
#
# Universe actual size:
# 0
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node77@3', 'Node66@3', 'Node42@3']
# n_set of length: 3
# CPC size after filtering: 3
# ['Node42@3', 'Node66@3', 'Node77@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node77@3']
#
# Universe actual size:
# 2
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node77@3', 'Node38@4']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node38@4', 'Node77@3']
#
# Universe actual size:
# 1
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node77@3', 'Node66@3', 'Node38@4']
# n_set of length: 3
# CPC size after filtering: 2
# ['Node66@3', 'Node77@3']
#
# Universe actual size:
# 0
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node77@3', 'Node66@3', 'Node42@3']
# n_set of length: 3
# CPC size after filtering: 3
# ['Node42@3', 'Node66@3', 'Node77@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node77@3']
#
# Universe actual size:
# 2
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node77@3', 'Node38@4']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node38@4', 'Node77@3']
#
# Universe actual size:
# 1
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node77@3', 'Node66@3', 'Node38@4']
# n_set of length: 3
# CPC size after filtering: 2
# ['Node66@3', 'Node77@3']
#
# Universe actual size:
# 0
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node77@3', 'Node66@3', 'Node42@3']
# n_set of length: 3
# CPC size after filtering: 3
# ['Node42@3', 'Node66@3', 'Node77@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node77@3']
#
# Universe actual size:
# 2
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node77@3', 'Node38@4']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node38@4', 'Node77@3']
#
# Universe actual size:
# 1
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node77@3', 'Node66@3', 'Node38@4']
# n_set of length: 3
# CPC size after filtering: 2
# ['Node66@3', 'Node77@3']
#
# Universe actual size:
# 0
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node77@3', 'Node66@3', 'Node42@3']
# n_set of length: 3
# CPC size after filtering: 3
# ['Node42@3', 'Node66@3', 'Node77@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node77@3']
#
# Universe actual size:
# 2
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node77@3', 'Node38@4']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node38@4', 'Node77@3']
#
# Universe actual size:
# 1
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node77@3', 'Node66@3', 'Node38@4']
# n_set of length: 3
# CPC size after filtering: 2
# ['Node66@3', 'Node77@3']
#
# Universe actual size:
# 0
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node77@3', 'Node66@3', 'Node42@3']
# n_set of length: 3
# CPC size after filtering: 3
# ['Node42@3', 'Node66@3', 'Node77@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC actual size:
# 1
# CPC contents:
# ['Node77@3']
#
# Universe actual size:
# 2
# CPC actual size:
# 2
# CPC contents:
# ['Node77@3', 'Node38@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 3
# CPC contents:
# ['Node77@3', 'Node38@4', 'Node42@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC actual size:
# 1
# CPC contents:
# ['Node77@3']
#
# Universe actual size:
# 2
# CPC actual size:
# 2
# CPC contents:
# ['Node77@3', 'Node38@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 3
# CPC contents:
# ['Node77@3', 'Node38@4', 'Node42@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
# Universe actual size:
# 3
# CPC actual size:
# 1
# CPC contents:
# ['Node77@3']
#
# Universe actual size:
# 2
# CPC actual size:
# 2
# CPC contents:
# ['Node77@3', 'Node38@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 3
# CPC contents:
# ['Node77@3', 'Node38@4', 'Node42@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC actual size:
# 1
# CPC contents:
# ['Node77@3']
#
# Universe actual size:
# 2
# CPC actual size:
# 2
# CPC contents:
# ['Node77@3', 'Node38@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 3
# CPC contents:
# ['Node77@3', 'Node38@4', 'Node42@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC actual size:
# 1
# CPC contents:
# ['Node77@3']
#
# Universe actual size:
# 2
# CPC actual size:
# 2
# CPC contents:
# ['Node77@3', 'Node38@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 3
# CPC contents:
# ['Node77@3', 'Node38@4', 'Node42@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC actual size:
# 1
# CPC contents:
# ['Node77@3']
#
# Universe actual size:
# 2
# CPC actual size:
# 2
# CPC contents:
# ['Node77@3', 'Node38@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 3
# CPC contents:
# ['Node77@3', 'Node38@4', 'Node42@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC actual size:
# 1
# CPC contents:
# ['Node77@3']
#
# Universe actual size:
# 2
# CPC actual size:
# 2
# CPC contents:
# ['Node77@3', 'Node38@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 3
# CPC contents:
# ['Node77@3', 'Node38@4', 'Node42@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC actual size:
# 1
# CPC contents:
# ['Node77@3']
#
# Universe actual size:
# 2
# CPC actual size:
# 2
# CPC contents:
# ['Node77@3', 'Node38@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 3
# CPC contents:
# ['Node77@3', 'Node38@4', 'Node42@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC actual size:
# 1
# CPC contents:
# ['Node77@3']
#
# Universe actual size:
# 2
# CPC actual size:
# 2
# CPC contents:
# ['Node77@3', 'Node38@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 3
# CPC contents:
# ['Node77@3', 'Node38@4', 'Node42@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC actual size:
# 1
# CPC contents:
# ['Node77@3']
#
# Universe actual size:
# 2
# CPC actual size:
# 2
# CPC contents:
# ['Node77@3', 'Node38@4']
#
# Universe actual size:
# 0
# CPC actual size:
# 3
# CPC contents:
# ['Node77@3', 'Node38@4', 'Node42@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node88@2']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node88@2']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node88@2']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node88@2']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node88@2']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC actual size:
# 1
# CPC contents:
# ['Node88@2']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC actual size:
# 1
# CPC contents:
# ['Node88@2']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC actual size:
# 1
# CPC contents:
# ['Node88@2']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC actual size:
# 1
# CPC contents:
# ['Node88@2']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC actual size:
# 1
# CPC contents:
# ['Node88@2']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC actual size:
# 1
# CPC contents:
# ['Node88@2']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC actual size:
# 1
# CPC contents:
# ['Node88@2']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC actual size:
# 1
# CPC contents:
# ['Node88@2']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC actual size:
# 1
# CPC contents:
# ['Node88@2']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC actual size:
# 1
# CPC contents:
# ['Node88@2']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 12
# CPC size before filtering: 5
# Size set for community selection phase will be of maximum: 4
# ['Node106@3', 'Node107@3', 'Node108@3', 'Node109@3', 'Node85@2']
# n_set of length: 5
# CPC size after filtering: 5
# ['Node85@2', 'Node109@3', 'Node108@3', 'Node107@3', 'Node106@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 12
# CPC size before filtering: 5
# Size set for community selection phase will be of maximum: 4
# ['Node106@3', 'Node107@3', 'Node109@3', 'Node85@2', 'Node108@3']
# n_set of length: 5
# CPC size after filtering: 5
# ['Node108@3', 'Node85@2', 'Node109@3', 'Node107@3', 'Node106@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 12
# CPC size before filtering: 5
# Size set for community selection phase will be of maximum: 4
# ['Node108@3', 'Node106@3', 'Node85@2', 'Node107@3', 'Node109@3']
# n_set of length: 5
# CPC size after filtering: 4
# ['Node107@3', 'Node85@2', 'Node106@3', 'Node108@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 12
# CPC size before filtering: 5
# Size set for community selection phase will be of maximum: 4
# ['Node85@2', 'Node109@3', 'Node106@3', 'Node107@3', 'Node108@3']
# n_set of length: 5
# CPC size after filtering: 3
# ['Node108@3', 'Node109@3', 'Node85@2']
#
# Universe actual size:
# 2
# CPC size before filtering: 4
# Size set for community selection phase will be of maximum: 3
# ['Node108@3', 'Node109@3', 'Node85@2', 'Node12@3']
# n_set of length: 4
# CPC size after filtering: 4
# ['Node12@3', 'Node85@2', 'Node109@3', 'Node108@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 12
# CPC size before filtering: 5
# Size set for community selection phase will be of maximum: 4
# ['Node108@3', 'Node106@3', 'Node109@3', 'Node85@2', 'Node107@3']
# n_set of length: 5
# CPC size after filtering: 4
# ['Node85@2', 'Node109@3', 'Node106@3', 'Node108@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 16
# CPC actual size:
# 1
# CPC contents:
# ['Node108@3']
#
# Universe actual size:
# 13
# CPC actual size:
# 2
# CPC contents:
# ['Node108@3', 'Node107@3']
#
# Universe actual size:
# 12
# CPC actual size:
# 3
# CPC contents:
# ['Node108@3', 'Node107@3', 'Node85@2']
#
# Universe actual size:
# 4
# CPC actual size:
# 4
# CPC contents:
# ['Node108@3', 'Node107@3', 'Node85@2', 'Node106@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 16
# CPC actual size:
# 1
# CPC contents:
# ['Node85@2']
#
# Universe actual size:
# 13
# CPC actual size:
# 2
# CPC contents:
# ['Node85@2', 'Node109@3']
#
# Universe actual size:
# 9
# CPC actual size:
# 3
# CPC contents:
# ['Node85@2', 'Node109@3', 'Node108@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 4
# CPC contents:
# ['Node85@2', 'Node109@3', 'Node108@3', 'Node12@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 5
# CPC contents:
# ['Node85@2', 'Node109@3', 'Node108@3', 'Node12@3', 'Node34@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 16
# CPC actual size:
# 1
# CPC contents:
# ['Node85@2']
#
# Universe actual size:
# 13
# CPC actual size:
# 2
# CPC contents:
# ['Node85@2', 'Node109@3']
#
# Universe actual size:
# 9
# CPC actual size:
# 3
# CPC contents:
# ['Node85@2', 'Node109@3', 'Node108@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 4
# CPC contents:
# ['Node85@2', 'Node109@3', 'Node108@3', 'Node12@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 5
# CPC contents:
# ['Node85@2', 'Node109@3', 'Node108@3', 'Node12@3', 'Node34@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 16
# CPC actual size:
# 1
# CPC contents:
# ['Node108@3']
#
# Universe actual size:
# 13
# CPC actual size:
# 2
# CPC contents:
# ['Node108@3', 'Node109@3']
#
# Universe actual size:
# 9
# CPC actual size:
# 3
# CPC contents:
# ['Node108@3', 'Node109@3', 'Node85@2']
#
# Universe actual size:
# 2
# CPC actual size:
# 4
# CPC contents:
# ['Node108@3', 'Node109@3', 'Node85@2', 'Node12@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 5
# CPC contents:
# ['Node108@3', 'Node109@3', 'Node85@2', 'Node12@3', 'Node34@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 16
# CPC actual size:
# 1
# CPC contents:
# ['Node108@3']
#
# Universe actual size:
# 13
# CPC actual size:
# 2
# CPC contents:
# ['Node108@3', 'Node109@3']
#
# Universe actual size:
# 9
# CPC actual size:
# 3
# CPC contents:
# ['Node108@3', 'Node109@3', 'Node85@2']
#
# Universe actual size:
# 2
# CPC actual size:
# 4
# CPC contents:
# ['Node108@3', 'Node109@3', 'Node85@2', 'Node12@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 5
# CPC contents:
# ['Node108@3', 'Node109@3', 'Node85@2', 'Node12@3', 'Node34@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 16
# CPC actual size:
# 1
# CPC contents:
# ['Node109@3']
#
# Universe actual size:
# 12
# CPC actual size:
# 2
# CPC contents:
# ['Node109@3', 'Node108@3']
#
# Universe actual size:
# 9
# CPC actual size:
# 3
# CPC contents:
# ['Node109@3', 'Node108@3', 'Node85@2']
#
# Universe actual size:
# 2
# CPC actual size:
# 4
# CPC contents:
# ['Node109@3', 'Node108@3', 'Node85@2', 'Node12@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 5
# CPC contents:
# ['Node109@3', 'Node108@3', 'Node85@2', 'Node12@3', 'Node34@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 16
# CPC actual size:
# 1
# CPC contents:
# ['Node109@3']
#
# Universe actual size:
# 12
# CPC actual size:
# 2
# CPC contents:
# ['Node109@3', 'Node85@2']
#
# Universe actual size:
# 9
# CPC actual size:
# 3
# CPC contents:
# ['Node109@3', 'Node85@2', 'Node108@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 4
# CPC contents:
# ['Node109@3', 'Node85@2', 'Node108@3', 'Node12@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 5
# CPC contents:
# ['Node109@3', 'Node85@2', 'Node108@3', 'Node12@3', 'Node34@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 16
# CPC actual size:
# 1
# CPC contents:
# ['Node85@2']
#
# Universe actual size:
# 13
# CPC actual size:
# 2
# CPC contents:
# ['Node85@2', 'Node109@3']
#
# Universe actual size:
# 9
# CPC actual size:
# 3
# CPC contents:
# ['Node85@2', 'Node109@3', 'Node108@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 4
# CPC contents:
# ['Node85@2', 'Node109@3', 'Node108@3', 'Node12@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 5
# CPC contents:
# ['Node85@2', 'Node109@3', 'Node108@3', 'Node12@3', 'Node34@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 16
# CPC actual size:
# 1
# CPC contents:
# ['Node107@3']
#
# Universe actual size:
# 15
# CPC actual size:
# 2
# CPC contents:
# ['Node107@3', 'Node109@3']
#
# Universe actual size:
# 12
# CPC actual size:
# 3
# CPC contents:
# ['Node107@3', 'Node109@3', 'Node85@2']
#
# Universe actual size:
# 4
# CPC actual size:
# 4
# CPC contents:
# ['Node107@3', 'Node109@3', 'Node85@2', 'Node108@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 16
# CPC actual size:
# 1
# CPC contents:
# ['Node106@3']
#
# Universe actual size:
# 14
# CPC actual size:
# 2
# CPC contents:
# ['Node106@3', 'Node108@3']
#
# Universe actual size:
# 11
# CPC actual size:
# 3
# CPC contents:
# ['Node106@3', 'Node108@3', 'Node109@3']
#
# Universe actual size:
# 2
# CPC actual size:
# 4
# CPC contents:
# ['Node106@3', 'Node108@3', 'Node109@3', 'Node85@2']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 9
# CPC size before filtering: 4
# Size set for community selection phase will be of maximum: 3
# ['Node106@3', 'Node109@3', 'Node108@3', 'Node107@3']
# n_set of length: 4
# CPC size after filtering: 4
# ['Node107@3', 'Node108@3', 'Node109@3', 'Node106@3']
#
# Universe actual size:
# 4
# CPC size before filtering: 5
# Size set for community selection phase will be of maximum: 4
# ['Node107@3', 'Node108@3', 'Node109@3', 'Node106@3', 'Node8@3']
# n_set of length: 5
# CPC size after filtering: 4
# ['Node8@3', 'Node109@3', 'Node108@3', 'Node107@3']
#
# Universe actual size:
# 0
# CPC size before filtering: 5
# Size set for community selection phase will be of maximum: 4
# ['Node109@3', 'Node108@3', 'Node107@3', 'Node8@3', 'Node281@4']
# n_set of length: 5
# CPC size after filtering: 5
# ['Node281@4', 'Node8@3', 'Node107@3', 'Node108@3', 'Node109@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 9
# CPC size before filtering: 4
# Size set for community selection phase will be of maximum: 3
# ['Node109@3', 'Node107@3', 'Node108@3', 'Node106@3']
# n_set of length: 4
# CPC size after filtering: 3
# ['Node108@3', 'Node107@3', 'Node109@3']
#
# Universe actual size:
# 4
# CPC size before filtering: 4
# Size set for community selection phase will be of maximum: 3
# ['Node108@3', 'Node107@3', 'Node109@3', 'Node8@3']
# n_set of length: 4
# CPC size after filtering: 4
# ['Node8@3', 'Node109@3', 'Node107@3', 'Node108@3']
#
# Universe actual size:
# 0
# CPC size before filtering: 5
# Size set for community selection phase will be of maximum: 4
# ['Node109@3', 'Node107@3', 'Node108@3', 'Node8@3', 'Node281@4']
# n_set of length: 5
# CPC size after filtering: 5
# ['Node281@4', 'Node8@3', 'Node108@3', 'Node107@3', 'Node109@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 9
# CPC size before filtering: 4
# Size set for community selection phase will be of maximum: 3
# ['Node106@3', 'Node109@3', 'Node108@3', 'Node107@3']
# n_set of length: 4
# CPC size after filtering: 4
# ['Node107@3', 'Node108@3', 'Node109@3', 'Node106@3']
#
# Universe actual size:
# 4
# CPC size before filtering: 5
# Size set for community selection phase will be of maximum: 4
# ['Node107@3', 'Node108@3', 'Node109@3', 'Node106@3', 'Node8@3']
# n_set of length: 5
# CPC size after filtering: 4
# ['Node8@3', 'Node109@3', 'Node108@3', 'Node107@3']
#
# Universe actual size:
# 0
# CPC size before filtering: 5
# Size set for community selection phase will be of maximum: 4
# ['Node109@3', 'Node108@3', 'Node107@3', 'Node8@3', 'Node281@4']
# n_set of length: 5
# CPC size after filtering: 5
# ['Node281@4', 'Node8@3', 'Node107@3', 'Node108@3', 'Node109@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 9
# CPC size before filtering: 4
# Size set for community selection phase will be of maximum: 3
# ['Node109@3', 'Node108@3', 'Node107@3', 'Node106@3']
# n_set of length: 4
# CPC size after filtering: 3
# ['Node107@3', 'Node108@3', 'Node109@3']
#
# Universe actual size:
# 4
# CPC size before filtering: 4
# Size set for community selection phase will be of maximum: 3
# ['Node107@3', 'Node108@3', 'Node109@3', 'Node8@3']
# n_set of length: 4
# CPC size after filtering: 4
# ['Node8@3', 'Node109@3', 'Node108@3', 'Node107@3']
#
# Universe actual size:
# 0
# CPC size before filtering: 5
# Size set for community selection phase will be of maximum: 4
# ['Node109@3', 'Node108@3', 'Node107@3', 'Node8@3', 'Node281@4']
# n_set of length: 5
# CPC size after filtering: 5
# ['Node281@4', 'Node8@3', 'Node107@3', 'Node108@3', 'Node109@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 9
# CPC size before filtering: 4
# Size set for community selection phase will be of maximum: 3
# ['Node106@3', 'Node109@3', 'Node107@3', 'Node108@3']
# n_set of length: 4
# CPC size after filtering: 4
# ['Node108@3', 'Node107@3', 'Node109@3', 'Node106@3']
#
# Universe actual size:
# 4
# CPC size before filtering: 5
# Size set for community selection phase will be of maximum: 4
# ['Node108@3', 'Node107@3', 'Node109@3', 'Node106@3', 'Node8@3']
# n_set of length: 5
# CPC size after filtering: 4
# ['Node8@3', 'Node109@3', 'Node107@3', 'Node108@3']
#
# Universe actual size:
# 1
# CPC size before filtering: 5
# Size set for community selection phase will be of maximum: 4
# ['Node109@3', 'Node107@3', 'Node108@3', 'Node8@3', 'Node281@4']
# n_set of length: 5
# CPC size after filtering: 5
# ['Node281@4', 'Node8@3', 'Node108@3', 'Node107@3', 'Node109@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 12
# CPC actual size:
# 1
# CPC contents:
# ['Node109@3']
#
# Universe actual size:
# 9
# CPC actual size:
# 2
# CPC contents:
# ['Node109@3', 'Node108@3']
#
# Universe actual size:
# 7
# CPC actual size:
# 3
# CPC contents:
# ['Node109@3', 'Node108@3', 'Node107@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 4
# CPC contents:
# ['Node109@3', 'Node108@3', 'Node107@3', 'Node8@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 5
# CPC contents:
# ['Node109@3', 'Node108@3', 'Node107@3', 'Node8@3', 'Node281@4']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 12
# CPC actual size:
# 1
# CPC contents:
# ['Node107@3']
#
# Universe actual size:
# 10
# CPC actual size:
# 2
# CPC contents:
# ['Node107@3', 'Node109@3']
#
# Universe actual size:
# 7
# CPC actual size:
# 3
# CPC contents:
# ['Node107@3', 'Node109@3', 'Node108@3']
#
# Universe actual size:
# 3
# CPC actual size:
# 4
# CPC contents:
# ['Node107@3', 'Node109@3', 'Node108@3', 'Node8@3']
#
# Universe actual size:
# 2
# CPC actual size:
# 5
# CPC contents:
# ['Node107@3', 'Node109@3', 'Node108@3', 'Node8@3', 'Node24@2']
# Universe actual size:
# 1
# CPC actual size:
# 6
# CPC contents:
# ['Node107@3', 'Node109@3', 'Node108@3', 'Node8@3', 'Node24@2', 'Node281@4']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 12
# CPC actual size:
# 1
# CPC contents:
# ['Node106@3']
#
# Universe actual size:
# 10
# CPC actual size:
# 2
# CPC contents:
# ['Node106@3', 'Node108@3']
#
# Universe actual size:
# 8
# CPC actual size:
# 3
# CPC contents:
# ['Node106@3', 'Node108@3', 'Node109@3']
#
# Universe actual size:
# 7
# CPC actual size:
# 4
# CPC contents:
# ['Node106@3', 'Node108@3', 'Node109@3', 'Node8@3']
#
# Universe actual size:
# 2
# CPC actual size:
# 5
# CPC contents:
# ['Node106@3', 'Node108@3', 'Node109@3', 'Node8@3', 'Node24@2']
#
# Universe actual size:
# 1
# CPC actual size:
# 6
# CPC contents:
# ['Node106@3', 'Node108@3', 'Node109@3', 'Node8@3', 'Node24@2', 'Node281@4']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 12
# CPC actual size:
# 1
# CPC contents:
# ['Node107@3']
#
# Universe actual size:
# 10
# CPC actual size:
# 2
# CPC contents:
# ['Node107@3', 'Node106@3']
#
# Universe actual size:
# 8
# CPC actual size:
# 3
# CPC contents:
# ['Node107@3', 'Node106@3', 'Node108@3']
#
# Universe actual size:
# 4
# CPC actual size:
# 4
# CPC contents:
# ['Node107@3', 'Node106@3', 'Node108@3', 'Node109@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 5
# CPC contents:
# ['Node107@3', 'Node106@3', 'Node108@3', 'Node109@3', 'Node8@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 6
# CPC contents:
# ['Node107@3', 'Node106@3', 'Node108@3', 'Node109@3', 'Node8@3', 'Node281@4']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 12
# CPC actual size:
# 1
# CPC contents:
# ['Node108@3']
#
# Universe actual size:
# 10
# CPC actual size:
# 2
# CPC contents:
# ['Node108@3', 'Node107@3']
#
# Universe actual size:
# 8
# CPC actual size:
# 3
# CPC contents:
# ['Node108@3', 'Node107@3', 'Node109@3']
#
# Universe actual size:
# 3
# CPC actual size:
# 4
# CPC contents:
# ['Node108@3', 'Node107@3', 'Node109@3', 'Node8@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 5
# CPC contents:
# ['Node108@3', 'Node107@3', 'Node109@3', 'Node8@3', 'Node281@4']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 12
# CPC actual size:
# 1
# CPC contents:
# ['Node108@3']
#
# Universe actual size:
# 10
# CPC actual size:
# 2
# CPC contents:
# ['Node108@3', 'Node107@3']
#
# Universe actual size:
# 8
# CPC actual size:
# 3
# CPC contents:
# ['Node108@3', 'Node107@3', 'Node106@3']
#
# Universe actual size:
# 5
# CPC actual size:
# 4
# CPC contents:
# ['Node108@3', 'Node107@3', 'Node106@3', 'Node109@3']
#
# Universe actual size:
# 2
# CPC actual size:
# 5
# CPC contents:
# ['Node108@3', 'Node107@3', 'Node106@3', 'Node109@3', 'Node8@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 6
# CPC contents:
# ['Node108@3', 'Node107@3', 'Node106@3', 'Node109@3', 'Node8@3', 'Node281@4']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 12
# CPC actual size:
# 1
# CPC contents:
# ['Node106@3']
#
# Universe actual size:
# 10
# CPC actual size:
# 2
# CPC contents:
# ['Node106@3', 'Node108@3']
#
# Universe actual size:
# 8
# CPC actual size:
# 3
# CPC contents:
# ['Node106@3', 'Node108@3', 'Node109@3']
#
# Universe actual size:
# 7
# CPC actual size:
# 4
# CPC contents:
# ['Node106@3', 'Node108@3', 'Node109@3', 'Node8@3']
#
# Universe actual size:
# 2
# CPC actual size:
# 5
# CPC contents:
# ['Node106@3', 'Node108@3', 'Node109@3', 'Node8@3', 'Node24@2']
#
# Universe actual size:
# 1
# CPC actual size:
# 6
# CPC contents:
# ['Node106@3', 'Node108@3', 'Node109@3', 'Node8@3', 'Node24@2', 'Node281@4']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 12
# CPC actual size:
# 1
# CPC contents:
# ['Node106@3']
#
# Universe actual size:
# 10
# CPC actual size:
# 2
# CPC contents:
# ['Node106@3', 'Node108@3']
#
# Universe actual size:
# 8
# CPC actual size:
# 3
# CPC contents:
# ['Node106@3', 'Node108@3', 'Node107@3']
#
# Universe actual size:
# 4
# CPC actual size:
# 4
# CPC contents:
# ['Node106@3', 'Node108@3', 'Node107@3', 'Node109@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 5
# CPC contents:
# ['Node106@3', 'Node108@3', 'Node107@3', 'Node109@3', 'Node8@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 6
# CPC contents:
# ['Node106@3', 'Node108@3', 'Node107@3', 'Node109@3', 'Node8@3', 'Node281@4']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 12
# CPC actual size:
# 1
# CPC contents:
# ['Node109@3']
#
# Universe actual size:
# 9
# CPC actual size:
# 2
# CPC contents:
# ['Node109@3', 'Node108@3']
#
# Universe actual size:
# 7
# CPC actual size:
# 3
# CPC contents:
# ['Node109@3', 'Node108@3', 'Node107@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 4
# CPC contents:
# ['Node109@3', 'Node108@3', 'Node107@3', 'Node8@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 5
# CPC contents:
# ['Node109@3', 'Node108@3', 'Node107@3', 'Node8@3', 'Node281@4']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 12
# CPC actual size:
# 1
# CPC contents:
# ['Node107@3']
#
# Universe actual size:
# 10
# CPC actual size:
# 2
# CPC contents:
# ['Node107@3', 'Node106@3']
#
# Universe actual size:
# 8
# CPC actual size:
# 3
# CPC contents:
# ['Node107@3', 'Node106@3', 'Node108@3']
#
# Universe actual size:
# 4
# CPC actual size:
# 4
# CPC contents:
# ['Node107@3', 'Node106@3', 'Node108@3', 'Node109@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 5
# CPC contents:
# ['Node107@3', 'Node106@3', 'Node108@3', 'Node109@3', 'Node8@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 6
# CPC contents:
# ['Node107@3', 'Node106@3', 'Node108@3', 'Node109@3', 'Node8@3', 'Node281@4']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 1
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node116@3']
#
# Universe actual size:
# 0
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node116@3', 'Node86@3']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node86@3', 'Node116@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 1
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node116@3']
#
# Universe actual size:
# 0
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node116@3', 'Node86@3']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node86@3', 'Node116@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 1
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node116@3']
#
# Universe actual size:
# 0
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node116@3', 'Node86@3']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node86@3', 'Node116@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 1
# CPC size before filtering: 1
# ...
# 2
# CPC contents:
# ['Node127@3', 'Node304@3']
#
# Universe actual size:
# 2
# CPC actual size:
# 3
# CPC contents:
# ['Node127@3', 'Node304@3', 'Node76@4']
#
# Universe actual size:
# 1
# CPC actual size:
# 4
# CPC contents:
# ['Node127@3', 'Node304@3', 'Node76@4', 'Node229@3']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node35@3']
#
# Universe actual size:
# 1
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node35@3', 'Node130@3']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node130@3', 'Node35@3']
#
# Universe actual size:
# 0
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node35@3', 'Node130@3', 'Node185@2']
# n_set of length: 3
# CPC size after filtering: 3
# ['Node185@2', 'Node130@3', 'Node35@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node35@3']
#
# Universe actual size:
# 1
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node35@3', 'Node130@3']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node130@3', 'Node35@3']
#
# Universe actual size:
# 0
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node35@3', 'Node130@3', 'Node185@2']
# n_set of length: 3
# CPC size after filtering: 3
# ['Node185@2', 'Node130@3', 'Node35@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node35@3']
#
# Universe actual size:
# 1
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node35@3', 'Node130@3']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node130@3', 'Node35@3']
#
# Universe actual size:
# 0
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node35@3', 'Node130@3', 'Node185@2']
# n_set of length: 3
# CPC size after filtering: 3
# ['Node185@2', 'Node130@3', 'Node35@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node35@3']
#
# Universe actual size:
# 1
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node35@3', 'Node130@3']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node130@3', 'Node35@3']
#
# Universe actual size:
# 0
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node35@3', 'Node130@3', 'Node185@2']
# n_set of length: 3
# CPC size after filtering: 3
# ['Node185@2', 'Node130@3', 'Node35@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node35@3']
#
# Universe actual size:
# 1
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node35@3', 'Node130@3']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node130@3', 'Node35@3']
#
# Universe actual size:
# 0
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node35@3', 'Node130@3', 'Node185@2']
# n_set of length: 3
# CPC size after filtering: 3
# ['Node185@2', 'Node130@3', 'Node35@3']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC actual size:
# 1
# CPC contents:
# ['Node35@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 2
# CPC contents:
# ['Node35@3', 'Node130@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 3
# CPC contents:
# ['Node35@3', 'Node130@3', 'Node185@2']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC actual size:
# 1
# CPC contents:
# ['Node35@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 2
# CPC contents:
# ['Node35@3', 'Node130@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 3
# CPC contents:
# ['Node35@3', 'Node130@3', 'Node185@2']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC actual size:
# 1
# CPC contents:
# ['Node35@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 2
# CPC contents:
# ['Node35@3', 'Node130@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 3
# CPC contents:
# ['Node35@3', 'Node130@3', 'Node185@2']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC actual size:
# 1
# CPC contents:
# ['Node35@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 2
# CPC contents:
# ['Node35@3', 'Node130@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 3
# CPC contents:
# ['Node35@3', 'Node130@3', 'Node185@2']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC actual size:
# 1
# CPC contents:
# ['Node35@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 2
# CPC contents:
# ['Node35@3', 'Node130@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 3
# CPC contents:
# ['Node35@3', 'Node130@3', 'Node185@2']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC actual size:
# 1
# CPC contents:
# ['Node35@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 2
# CPC contents:
# ['Node35@3', 'Node130@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 3
# CPC contents:
# ['Node35@3', 'Node130@3', 'Node185@2']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC actual size:
# 1
# CPC contents:
# ['Node35@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 2
# CPC contents:
# ['Node35@3', 'Node130@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 3
# CPC contents:
# ['Node35@3', 'Node130@3', 'Node185@2']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC actual size:
# 1
# CPC contents:
# ['Node35@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 2
# CPC contents:
# ['Node35@3', 'Node130@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 3
# CPC contents:
# ['Node35@3', 'Node130@3', 'Node185@2']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC actual size:
# 1
# CPC contents:
# ['Node35@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 2
# CPC contents:
# ['Node35@3', 'Node130@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 3
# CPC contents:
# ['Node35@3', 'Node130@3', 'Node185@2']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 3
# CPC actual size:
# 1
# CPC contents:
# ['Node35@3']
#
# Universe actual size:
# 1
# CPC actual size:
# 2
# CPC contents:
# ['Node35@3', 'Node130@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 3
# CPC contents:
# ['Node35@3', 'Node130@3', 'Node185@2']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
# Entering Phase I
# MMPC_beggining:
# 369
# Entering Phase I
# MMPC_beggining:
# 369
# Entering Phase I
# MMPC_beggining:
# 369
# Entering Phase I
# MMPC_beggining:
# 369
# Entering Phase I
# MMPC_beggining:
# 369
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node113@4']
#
# Universe actual size:
# 3
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node113@4', 'Node325@3']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node325@3', 'Node113@4']
#
# Universe actual size:
# 2
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node113@4', 'Node325@3', 'Node300@4']
# n_set of length: 3
# CPC size after filtering: 2
# ['Node325@3', 'Node113@4']
#
# Universe actual size:
# 1
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node113@4', 'Node325@3', 'Node318@4']
# n_set of length: 3
# CPC size after filtering: 2
# ['Node325@3', 'Node113@4']
#
# Universe actual size:
# 0
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node113@4', 'Node325@3', 'Node354@4']
# n_set of length: 3
# CPC size after filtering: 3
# ['Node354@4', 'Node325@3', 'Node113@4']
# Entering Phase I
# MMPC_beggining:
# 369
# Universe actual size:
# 5
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node113@4']
#
# Universe actual size:
# 3
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node113@4', 'Node325@3']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node325@3', 'Node113@4']
#
# Universe actual size:
# 2
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node113@4', 'Node325@3', 'Node300@4']
# n_set of length: 3
# CPC size after filtering: 2
# ['Node325@3', 'Node113@4']
#
# Universe actual size:
# 1
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node113@4', 'Node325@3', 'Node318@4']
# n_set of length: 3
# CPC size after filtering: 2
# ['Node325@3', 'Node113@4']
#
# Universe actual size:
# 0
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node113@4', 'Node325@3', 'Node354@4']
# n_set of length: 3
# CPC size after filtering: 3
# ['Node354@4', 'Node325@3', 'Node113@4']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node113@4']
#
# Universe actual size:
# 3
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node113@4', 'Node325@3']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node325@3', 'Node113@4']
#
# Universe actual size:
# 2
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node113@4', 'Node325@3', 'Node300@4']
# n_set of length: 3
# CPC size after filtering: 2
# ['Node325@3', 'Node113@4']
#
# Universe actual size:
# 1
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node113@4', 'Node325@3', 'Node318@4']
# n_set of length: 3
# CPC size after filtering: 2
# ['Node325@3', 'Node113@4']
#
# Universe actual size:
# 0
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node113@4', 'Node325@3', 'Node354@4']
# n_set of length: 3
# CPC size after filtering: 3
# ['Node354@4', 'Node325@3', 'Node113@4']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node113@4']
#
# Universe actual size:
# 3
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node113@4', 'Node325@3']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node325@3', 'Node113@4']
#
# Universe actual size:
# 2
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node113@4', 'Node325@3', 'Node300@4']
# n_set of length: 3
# CPC size after filtering: 2
# ['Node325@3', 'Node113@4']
#
# Universe actual size:
# 1
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node113@4', 'Node325@3', 'Node318@4']
# n_set of length: 3
# CPC size after filtering: 2
# ['Node325@3', 'Node113@4']
#
# Universe actual size:
# 0
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node113@4', 'Node325@3', 'Node354@4']
# n_set of length: 3
# CPC size after filtering: 3
# ['Node354@4', 'Node325@3', 'Node113@4']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC size before filtering: 1
# CPC size after filtering: 1
# ['Node113@4']
#
# Universe actual size:
# 3
# CPC size before filtering: 2
# Size set for community selection phase will be of maximum: 2
# ['Node113@4', 'Node325@3']
# n_set of length: 2
# CPC size after filtering: 2
# ['Node325@3', 'Node113@4']
#
# Universe actual size:
# 2
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node113@4', 'Node325@3', 'Node300@4']
# n_set of length: 3
# CPC size after filtering: 2
# ['Node325@3', 'Node113@4']
#
# Universe actual size:
# 1
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node113@4', 'Node325@3', 'Node318@4']
# n_set of length: 3
# CPC size after filtering: 2
# ['Node325@3', 'Node113@4']
#
# Universe actual size:
# 0
# CPC size before filtering: 3
# Size set for community selection phase will be of maximum: 3
# ['Node113@4', 'Node325@3', 'Node354@4']
# n_set of length: 3
# CPC size after filtering: 3
# ['Node354@4', 'Node325@3', 'Node113@4']
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC actual size:
# 1
# CPC contents:
# ['Node113@4']
#
# Universe actual size:
# 3
# CPC actual size:
# 2
# CPC contents:
# ['Node113@4', 'Node325@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 3
# CPC contents:
# ['Node113@4', 'Node325@3', 'Node354@4']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
#
# Universe actual size:
# 5
# CPC actual size:
# 1
# CPC contents:
# ['Node113@4']
#
# Universe actual size:
# 3
# CPC actual size:
# 2
# CPC contents:
# ['Node113@4', 'Node325@3']
#
# Universe actual size:
# 0
# CPC actual size:
# 3
# CPC contents:
# ['Node113@4', 'Node325@3', 'Node354@4']
#
# Entering Phase II
# Entering Phase I
# MMPC_beggining:
# 369
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-b71c0f84e9d6> in <module>()
# ----> 1 seq_testing.test_models()
#
# <ipython-input-2-6dbe1a969221> in test_models(self)
#     123     def test_models(self):
#     124         PCs = self.__getNodeDicts()
# --> 125         model_pcs = self.__evaluate(PCs)
#     126 #         scored_pcs = Parallel(n_jobs=10)(map(delayed(self.__scorePC),PCs))
#     127 #         self._results = scored_pcs
#
# <ipython-input-2-6dbe1a969221> in __evaluate(self, PCs)
#      88                     for shuffle_c in range(0,self._n_shuffles):
#      89                         self._mmpc_models[model_c].shuffle_rows()
# ---> 90                         model_results = self._mmpc_models[model_c].evaluate(pcs_index[nodes_c])
#      91                         results_dict = {}
#      92                         results_dict['model_name'] = self._model_names[model_c]
#
# ~/sdelrio/GeneInteractions/GeneInteractionsBN/FeatureSelection/MMPC_opt.ipynb in evaluate(self, index)
#      66     "        CPC=[]\n",
#      67     "        alpha = self._alpha\n",
# ---> 68     "        X = self._arrX\n",
#      69     "        TargetNode = [x for x in self._arrX if x['name'].split('@')[0] == (\"Node\"+str(index+1))][0]\n",
#      70     "        Universe = arrayUniverse(TargetNode['name'], self._arrX)\n",
#
# ~/sdelrio/GeneInteractions/GeneInteractionsBN/FeatureSelection/MMPC_opt.ipynb in __mm_heuristic(self, TargetNode, CPC, Universe, X, alpha)
#     135   },
#     136   {
# --> 137    "cell_type": "code",
#     138    "execution_count": 12,
#     139    "metadata": {},
#
# ~/sdelrio/GeneInteractions/GeneInteractionsBN/FeatureSelection/MMPC_opt.ipynb in __min_assoc(self, TargetNode, Xi, Z, fixedCondVars, X, alpha)
#     147     "        fixedCondVars = []\n",
#     148     "        if (len(CPC)>0):\n",
# --> 149     "            Z = CPC[0:-1]           # all but the last one   \n",
#     150     "            fixedCondVars = [CPC[-1]] # we use last one\n",
#     151     "        for i in range(len(Universe)-1,-1,-1):\n",
#
# ~/sdelrio/GeneInteractions/GeneInteractionsBN/FeatureSelection/Utilities/G2Dependency.py in dependency(self, TargetNode, Xi, CondVars, alpha)
#     131             G2 = 2*G2
#     132
# --> 133         assoc = (alpha - (1 - chi2.cdf(G2,Dedf)))/alpha
#     134
#     135         if assoc<0:
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py in cdf(self, x, *args, **kwds)
#    1743         if np.any(cond):  # call only if at least 1 entry
#    1744             goodargs = argsreduce(cond, *((x,)+args))
# -> 1745             place(output, cond, self._cdf(*goodargs))
#    1746         if output.ndim == 0:
#    1747             return output[()]
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py in place(arr, mask, vals)
#    2348
#    2349
# -> 2350 def place(arr, mask, vals):
#    2351     """
#    2352     Change elements of an array based on conditional and input values.
#
# KeyboardInterrupt:
